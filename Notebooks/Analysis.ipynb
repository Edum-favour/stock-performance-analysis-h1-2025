# %%
# Install the yfinance library using pip
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\hp\anaconda3\lib\site-packages (0.2.59)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (0.10.0)
# Requirement already satisfied: protobuf<6,>=5.29.0 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (5.29.4)
# Requirement already satisfied: websockets>=11.0 in c:\users\hp\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\hp\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\hp\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# aext-assistant                    4.1.0
# aext-assistant-server             4.1.0
# aext-core                         4.1.0
# aext-core-server                  4.1.0
# aext-panels                       4.1.0
# aext-panels-server                4.1.0
# aext-project-filebrowser-server   4.1.0
# aext-share-notebook               4.1.0
# aext-share-notebook-server        4.1.0
# aext-shared                       4.1.0
# aext-toolbox                      4.1.0
# aiobotocore                       2.12.3
# aiohappyeyeballs                  2.4.0
# aiohttp                           3.10.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# alembic                           1.13.3
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.4.1
# anaconda-client                   1.13.0
# anaconda-cloud-auth               0.7.2
# anaconda-navigator                2.6.4
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           6.1.3
# astropy-iers-data                 0.2024.9.2.0.33.23
# asttokens                         2.0.5
# async-lru                         2.0.4
# atomicwrites                      1.4.0
# attrs                             23.1.0
# Automat                           20.2.0
# autopep8                          2.0.4
# Babel                             2.11.0
# bcrypt                            3.2.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# black                             24.8.0
# bleach                            4.1.0
# blinker                           1.6.2
# bokeh                             3.6.0
# boltons                           23.0.0
# botocore                          1.34.69
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# cachetools                        5.3.3
# certifi                           2024.12.14
# cffi                              1.17.1
# chardet                           4.0.0
# charset-normalizer                3.3.2
# click                             8.1.7
# cloudpickle                       3.0.0
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.1
# conda                             24.11.3
# conda-build                       24.9.0
# conda-content-trust               0.2.0
# conda_index                       0.5.0
# conda-libmamba-solver             24.9.0
# conda-pack                        0.7.1
# conda-package-handling            2.3.0
# conda_package_streaming           0.10.0
# conda-repo-cli                    1.0.114
# conda-token                       0.5.0+1.g2209e04
# constantly                        23.10.4
# contourpy                         1.2.0
# cookiecutter                      2.6.0
# cryptography                      43.0.0
# cssselect                         1.2.0
# curl_cffi                         0.10.0
# cycler                            0.11.0
# cytoolz                           0.12.2
# dask                              2024.8.2
# dask-expr                         1.1.13
# datashader                        0.16.3
# debugpy                           1.6.7
# decorator                         5.1.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2024.8.2
# distro                            1.9.0
# docstring-to-markdown             0.11
# docutils                          0.18.1
# et-xmlfile                        1.1.0
# executing                         0.8.3
# fastjsonschema                    2.16.2
# filelock                          3.13.1
# flake8                            7.0.0
# Flask                             3.0.3
# fonttools                         4.51.0
# frozendict                        2.4.2
# frozenlist                        1.4.0
# fsspec                            2024.6.1
# gensim                            4.3.3
# gitdb                             4.0.7
# GitPython                         3.1.43
# greenlet                          3.0.1
# h11                               0.14.0
# h5py                              3.11.0
# HeapDict                          1.0.1
# holoviews                         1.19.1
# httpcore                          1.0.2
# httpx                             0.27.0
# hvplot                            0.11.0
# hyperlink                         21.0.0
# idna                              3.7
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# importlib-metadata                7.0.1
# incremental                       22.10.0
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            2.0.7
# intervaltree                      3.1.0
# ipykernel                         6.28.0
# ipython                           8.27.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.8.1
# isort                             5.13.2
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jedi                              0.19.1
# jellyfish                         1.0.1
# Jinja2                            3.1.4
# jmespath                          1.0.1
# joblib                            1.4.2
# json5                             0.9.6
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.23.0
# jsonschema-specifications         2023.7.1
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.10.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.14.1
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.2.5
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.27.3
# jupyterlab-widgets                1.0.0
# keyring                           24.3.1
# kiwisolver                        1.4.4
# lazy_loader                       0.4
# lazy-object-proxy                 1.10.0
# lckr_jupyterlab_variableinspector 3.1.0
# libarchive-c                      5.1
# libmambapy                        1.5.8
# linkify-it-py                     2.0.0
# llvmlite                          0.43.0
# lmdb                              1.4.1
# locket                            1.0.0
# lxml                              5.2.1
# lz4                               4.3.2
# Mako                              1.2.3
# Markdown                          3.4.1
# markdown-it-py                    2.2.0
# MarkupSafe                        2.1.3
# matplotlib                        3.9.2
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.1.2
# mistune                           2.0.4
# mkl_fft                           1.3.10
# mkl_random                        1.2.7
# mkl-service                       2.4.0
# more-itertools                    10.3.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.0.4
# multipledispatch                  0.6.0
# multitasking                      0.0.11
# mypy                              1.11.2
# mypy-extensions                   1.0.0
# navigator-updater                 0.5.1
# nb_conda_kernels                  2.5.2
# nbclient                          0.8.0
# nbconvert                         7.16.4
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.3
# nltk                              3.9.1
# notebook                          7.2.2
# notebook_shim                     0.2.3
# numba                             0.60.0
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.7.0
# openpyxl                          3.1.5
# overrides                         7.4.0
# packaging                         24.1
# pandas                            2.2.2
# pandocfilters                     1.5.0
# panel                             1.5.2
# param                             2.1.1
# paramiko                          2.8.1
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# pathspec                          0.10.3
# patsy                             0.5.6
# peewee                            3.18.1
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            10.4.0
# pip                               24.2
# pkce                              1.0.3
# pkginfo                           1.10.0
# platformdirs                      3.10.0
# plotly                            5.24.1
# pluggy                            1.0.0
# ply                               3.11
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.43
# Protego                           0.1.16
# protobuf                          5.29.4
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyarrow                           16.1.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.11.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.3
# pydantic                          2.8.2
# pydantic_core                     2.20.1
# pydantic-settings                 2.6.1
# pydeck                            0.8.0
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.4
# pyflakes                          3.2.0
# Pygments                          2.15.1
# PyJWT                             2.8.0
# pylint                            2.16.2
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.1.0
# pyOpenSSL                         24.2.1
# pyparsing                         3.1.2
# PyQt5                             5.15.10
# PyQt5-sip                         12.13.0
# PyQtWebEngine                     5.15.6
# PySocks                           1.7.1
# pytest                            7.4.4
# python-dateutil                   2.9.0.post0
# python-dotenv                     0.21.0
# python-json-logger                2.0.7
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.10.0
# python-slugify                    5.0.2
# pytoolconfig                      1.2.6
# pytz                              2024.1
# pyviz_comms                       3.0.2
# PyWavelets                        1.7.0
# pywin32                           305.1
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.10
# PyYAML                            6.0.1
# pyzmq                             25.1.2
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.3.1
# qtconsole                         5.5.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# readchar                          4.0.5
# referencing                       0.30.2
# regex                             2024.9.11
# requests                          2.32.3
# requests-file                     1.5.1
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.7.1
# rope                              1.12.0
# rpds-py                           0.10.6
# Rtree                             1.0.1
# ruamel.yaml                       0.18.6
# ruamel.yaml.clib                  0.2.8
# ruamel-yaml-conda                 0.17.21
# s3fs                              2024.6.1
# scikit-image                      0.24.0
# scikit-learn                      1.5.1
# scipy                             1.13.1
# Scrapy                            2.11.1
# seaborn                           0.13.2
# semver                            3.0.2
# Send2Trash                        1.8.2
# sentry-sdk                        2.18.0
# service-identity                  18.1.0
# setuptools                        75.1.0
# shellingham                       1.5.0
# sip                               6.7.12
# six                               1.16.0
# smart-open                        5.2.1
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            7.3.7
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.10
# spyder                            5.5.1
# spyder-kernels                    2.5.0
# SQLAlchemy                        2.0.34
# stack-data                        0.2.0
# statsmodels                       0.14.2
# streamlit                         1.37.1
# sympy                             1.13.2
# tables                            3.10.1
# tabulate                          0.9.0
# tblib                             1.7.0
# tenacity                          8.2.3
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.2.1
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# tinycss2                          1.2.1
# tldextract                        5.1.2
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.11.1
# toolz                             0.12.0
# tornado                           6.4.1
# tqdm                              4.66.5
# traitlets                         5.14.3
# truststore                        0.8.0
# Twisted                           23.10.0
# twisted-iocpsupport               1.0.2
# typer                             0.9.0
# typing_extensions                 4.11.0
# tzdata                            2023.3
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# unicodedata2                      15.1.0
# Unidecode                         1.3.8
# urllib3                           2.2.3
# w3lib                             2.1.2
# watchdog                          4.0.1
# wcwidth                           0.2.5
# webencodings                      0.5.1
# websocket-client                  1.8.0
# websockets                        15.0.1
# Werkzeug                          3.0.3
# whatthepatch                      1.0.2
# wheel                             0.44.0
# widgetsnbextension                3.6.6
# win-inet-pton                     1.1.0
# wrapt                             1.14.1
# xarray                            2023.6.0
# xlwings                           0.32.1
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.11.0
# yfinance                          0.2.59
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load libraries
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
# Get S&P 500 tickers from yahoo finance
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
sp500_table = pd.read_html(url)[0]
sp500_table["Symbol"] = sp500_table["Symbol"].str.strip().str.upper()
sp500_table["Security"] = sp500_table["Security"].str.strip()
ticker_name_map = dict(zip(sp500_table["Symbol"], sp500_table["Security"]))
tickers = list(ticker_name_map.keys())
print(tickers[:10])
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A']

# %%
# Load dividend aristocrats from local CSV
aristocrats_df = pd.read_excel("aristocrats.csv.xlsx")
aristocrat_tickers = aristocrats_df["Ticker"].str.strip().str.upper().tolist()
aristocrat_tickers
# Out:
# ['BDX',
#  'PEP',
#  'NDSN',
#  'PPG',
#  'TGT',
#  'SYY',
#  'NUE',
#  'HRL',
#  'LOW',
#  'JNJ',
#  'SPGI',
#  'GPC',
#  'MDT',
#  'EMR',
#  'BF.B',
#  'ALB',
#  'FDS',
#  'ADM',
#  'ITW',
#  'GWW',
#  'MKC',
#  'KO',
#  'AOS',
#  'ADP',
#  'ROP',
#  'CHD',
#  'APD',
#  'BRO',
#  'DOV',
#  'CL',
#  'ABBV',
#  'CAT',
#  'ATO',
#  'PNR',
#  'GD',
#  'ABT',
#  'MCD',
#  'ERIE',
#  'PG',
#  'CB',
#  'CTAS',
#  'WMT',
#  'SHW',
#  'AFL',
#  'WST',
#  'LIN',
#  'CINF',
#  'ECL',
#  'KVUE',
#  'ES',
#  'TROW',
#  'SWK',
#  'NEE',
#  'CLX',
#  'BEN',
#  'ED',
#  'KMB',
#  'FRT',
#  'EXPD',
#  'CAH',
#  'SJM',
#  'ESS',
#  'CHRW',
#  'FAST',
#  'O',
#  'XOM',
#  'IBM',
#  'AMCR',
#  'CVX']

# %%
# Define the period of analysis
start_date = "2025-01-01"
end_date = "2025-06-30"

# %%
# Get stock data from yahoo finance
def get_stock_data(ticker):
    try:
        stock = yf.Ticker(ticker)
        
        hist = stock.history(start=start_date, end=end_date)
        if hist.empty:
            print(f"{ticker}: No price data - retrying once...")
            time.sleep(0.5)
            hist = stock.history(start=start_date, end=end_date)

        if hist.empty:
            print(f"{ticker}: Still no price data - skipping.")
            return None

        # Calculate price return + momentum
        start_price = hist.iloc[0]["Close"]
        end_price = hist.iloc[-1]["Close"]
        price_return = ((end_price - start_price) / start_price) * 100
        momentum = end_price - start_price

        # Volatility (Daily returns standard deviation)
        hist["Daily Return"] = hist["Close"].pct_change()
        volatility = hist["Daily Return"].std() * (252 ** 0.5) * 100
       
        # Dividend Yield
        dividends = stock.dividends
        q1_dividends = dividends.loc[(dividends.index >= start_date) & (dividends.index <= end_date)].sum()
        dividend_yield = (q1_dividends / start_price) * 100

        # Liquidity
        avg_volume = hist["Volume"].mean()

        # Total Return
        total_return = price_return + dividend_yield

        # Extract fundamentals from yahoo finance
        try:
            info = stock.info
            roe = info.get("returnOnEquity", None)
            roe = roe * 100 if roe is not None else None
            pe_ratio = info.get("trailingPE", None)
        except:
            roe = None
            pe_ratio = None
        
        return {
        "Ticker": ticker,
        "Company Name": ticker_name_map.get(ticker, ""),
        "Start Price": round(start_price, 2),
        "End Price": round(end_price, 2),
        "Price Return %": round(price_return, 2),
        "Q1 Dividends ($)": round(q1_dividends, 2),
        "Dividend Yield %": round(dividend_yield, 2),
        "Total Return %": round(total_return, 2),
        "Volatility %": round(volatility, 2),
        "Avg Daily Volume": round(avg_volume),
        "Momentum ($)": round(momentum, 2),
        "ROE": round(roe, 2) if roe is not None else None,
        "P/E Ratio": round(pe_ratio, 2) if pe_ratio is not None else None
        
        }
    except Exception as e:
        return None

# %%
# Loop through over 500 S&P tickers and fetch stock metrics
results = []

for i, ticker in enumerate(tickers):
    ticker = ticker.replace(".", "-")
    print(f"[{i+1}/{len(tickers)}] Checking: {ticker}")
    data = get_stock_data(ticker)
    if data:
        print(" Appending:", data)
        results.append(data)

print(f"\n✅ Completed. Total stocks found: {len(results)}")
# Out:
# [1/502] Checking: MMM
#  Appending: {'Ticker': 'MMM', 'Company Name': '3M', 'Start Price': 128.43, 'End Price': 152.02, 'Price Return %': 18.36, 'Q1 Dividends ($)': 1.46, 'Dividend Yield %': 1.14, 'Total Return %': 19.5, 'Volatility %': 34.98, 'Avg Daily Volume': 3878507, 'Momentum ($)': 23.59, 'ROE': 93.82, 'P/E Ratio': 19.05}
# [2/502] Checking: AOS
#  Appending: {'Ticker': 'AOS', 'Company Name': 'A. O. Smith', 'Start Price': 66.65, 'End Price': 65.65, 'Price Return %': -1.5, 'Q1 Dividends ($)': 0.68, 'Dividend Yield %': 1.02, 'Total Return %': -0.48, 'Volatility %': 26.8, 'Avg Daily Volume': 1582531, 'Momentum ($)': -1.0, 'ROE': 27.97, 'P/E Ratio': 18.97}
# [3/502] Checking: ABT
#  Appending: {'Ticker': 'ABT', 'Company Name': 'Abbott Laboratories', 'Start Price': 112.33, 'End Price': 134.38, 'Price Return %': 19.63, 'Q1 Dividends ($)': 1.18, 'Dividend Yield %': 1.05, 'Total Return %': 20.68, 'Volatility %': 23.48, 'Avg Daily Volume': 6853778, 'Momentum ($)': 22.05, 'ROE': 30.65, 'P/E Ratio': 17.46}
# [4/502] Checking: ABBV
#  Appending: {'Ticker': 'ABBV', 'Company Name': 'AbbVie', 'Start Price': 176.14, 'End Price': 182.31, 'Price Return %': 3.51, 'Q1 Dividends ($)': 3.28, 'Dividend Yield %': 1.86, 'Total Return %': 5.37, 'Volatility %': 28.84, 'Avg Daily Volume': 7103250, 'Momentum ($)': 6.17, 'ROE': 88.4, 'P/E Ratio': 80.54}
# [5/502] Checking: ACN
#  Appending: {'Ticker': 'ACN', 'Company Name': 'Accenture', 'Start Price': 345.63, 'End Price': 295.46, 'Price Return %': -14.52, 'Q1 Dividends ($)': 2.96, 'Dividend Yield %': 0.86, 'Total Return %': -13.66, 'Volatility %': 30.1, 'Avg Daily Volume': 3352561, 'Momentum ($)': -50.17, 'ROE': 26.93, 'P/E Ratio': 24.27}
# [6/502] Checking: ADBE
#  Appending: {'Ticker': 'ADBE', 'Company Name': 'Adobe Inc.', 'Start Price': 441.0, 'End Price': 385.83, 'Price Return %': -12.51, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -12.51, 'Volatility %': 35.03, 'Avg Daily Volume': 3824672, 'Momentum ($)': -55.17, 'ROE': 52.25, 'P/E Ratio': 24.27}
# [7/502] Checking: AMD
#  Appending: {'Ticker': 'AMD', 'Company Name': 'Advanced Micro Devices', 'Start Price': 120.63, 'End Price': 143.81, 'Price Return %': 19.22, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 19.22, 'Volatility %': 61.04, 'Avg Daily Volume': 42794721, 'Momentum ($)': 23.18, 'ROE': 3.9, 'P/E Ratio': 100.66}
# [8/502] Checking: AES
#  Appending: {'Ticker': 'AES', 'Company Name': 'AES Corporation', 'Start Price': 12.62, 'End Price': 10.72, 'Price Return %': -15.06, 'Q1 Dividends ($)': 0.35, 'Dividend Yield %': 2.79, 'Total Return %': -12.27, 'Volatility %': 51.72, 'Avg Daily Volume': 15870340, 'Momentum ($)': -1.9, 'ROE': 5.58, 'P/E Ratio': 6.26}
# [9/502] Checking: AFL
#  Appending: {'Ticker': 'AFL', 'Company Name': 'Aflac', 'Start Price': 101.23, 'End Price': 105.07, 'Price Return %': 3.79, 'Q1 Dividends ($)': 1.16, 'Dividend Yield %': 1.15, 'Total Return %': 4.94, 'Volatility %': 24.89, 'Avg Daily Volume': 2130106, 'Momentum ($)': 3.84, 'ROE': 14.41, 'P/E Ratio': 16.26}
# [10/502] Checking: A
#  Appending: {'Ticker': 'A', 'Company Name': 'Agilent Technologies', 'Start Price': 132.87, 'End Price': 118.92, 'Price Return %': -10.5, 'Q1 Dividends ($)': 0.25, 'Dividend Yield %': 0.19, 'Total Return %': -10.31, 'Volatility %': 34.63, 'Avg Daily Volume': 2074611, 'Momentum ($)': -13.95, 'ROE': 18.88, 'P/E Ratio': 29.97}
# [11/502] Checking: APD
#  Appending: {'Ticker': 'APD', 'Company Name': 'Air Products', 'Start Price': 279.78, 'End Price': 280.56, 'Price Return %': 0.28, 'Q1 Dividends ($)': 3.56, 'Dividend Yield %': 1.27, 'Total Return %': 1.55, 'Volatility %': 29.09, 'Avg Daily Volume': 1410207, 'Momentum ($)': 0.77, 'ROE': 9.58, 'P/E Ratio': 41.99}
# [12/502] Checking: ABNB
#  Appending: {'Ticker': 'ABNB', 'Company Name': 'Airbnb', 'Start Price': 131.48, 'End Price': 134.52, 'Price Return %': 2.31, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 2.31, 'Volatility %': 47.42, 'Avg Daily Volume': 5517291, 'Momentum ($)': 3.04, 'ROE': 32.06, 'P/E Ratio': 34.64}
# [13/502] Checking: AKAM
#  Appending: {'Ticker': 'AKAM', 'Company Name': 'Akamai Technologies', 'Start Price': 95.42, 'End Price': 79.6, 'Price Return %': -16.58, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -16.58, 'Volatility %': 49.73, 'Avg Daily Volume': 2589455, 'Momentum ($)': -15.82, 'ROE': 9.82, 'P/E Ratio': 26.67}
# [14/502] Checking: ALB
#  Appending: {'Ticker': 'ALB', 'Company Name': 'Albemarle Corporation', 'Start Price': 84.2, 'End Price': 64.95, 'Price Return %': -22.87, 'Q1 Dividends ($)': 0.81, 'Dividend Yield %': 0.96, 'Total Return %': -21.9, 'Volatility %': 59.46, 'Avg Daily Volume': 3129052, 'Momentum ($)': -19.25, 'ROE': -9.99, 'P/E Ratio': None}
# [15/502] Checking: ARE
#  Appending: {'Ticker': 'ARE', 'Company Name': 'Alexandria Real Estate Equities', 'Start Price': 94.42, 'End Price': 72.05, 'Price Return %': -23.7, 'Q1 Dividends ($)': 2.64, 'Dividend Yield %': 2.8, 'Total Return %': -20.9, 'Volatility %': 33.95, 'Avg Daily Volume': 1597029, 'Momentum ($)': -22.37, 'ROE': 1.48, 'P/E Ratio': 101.21}
# [16/502] Checking: ALGN
#  Appending: {'Ticker': 'ALGN', 'Company Name': 'Align Technology', 'Start Price': 208.49, 'End Price': 188.52, 'Price Return %': -9.58, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -9.58, 'Volatility %': 41.7, 'Avg Daily Volume': 1059022, 'Momentum ($)': -19.97, 'ROE': 10.84, 'P/E Ratio': 35.85}
# [17/502] Checking: ALLE
#  Appending: {'Ticker': 'ALLE', 'Company Name': 'Allegion', 'Start Price': 128.07, 'End Price': 143.89, 'Price Return %': 12.36, 'Q1 Dividends ($)': 0.51, 'Dividend Yield %': 0.4, 'Total Return %': 12.75, 'Volatility %': 29.33, 'Avg Daily Volume': 989688, 'Momentum ($)': 15.82, 'ROE': 42.05, 'P/E Ratio': 20.8}
# [18/502] Checking: LNT
#  Appending: {'Ticker': 'LNT', 'Company Name': 'Alliant Energy', 'Start Price': 57.53, 'End Price': 60.35, 'Price Return %': 4.9, 'Q1 Dividends ($)': 1.01, 'Dividend Yield %': 1.76, 'Total Return %': 6.66, 'Volatility %': 21.06, 'Avg Daily Volume': 1994086, 'Momentum ($)': 2.82, 'ROE': 10.71, 'P/E Ratio': 21.22}
# [19/502] Checking: ALL
#  Appending: {'Ticker': 'ALL', 'Company Name': 'Allstate', 'Start Price': 190.08, 'End Price': 195.76, 'Price Return %': 2.99, 'Q1 Dividends ($)': 2.0, 'Dividend Yield %': 1.05, 'Total Return %': 4.04, 'Volatility %': 29.51, 'Avg Daily Volume': 1794485, 'Momentum ($)': 5.68, 'ROE': 19.72, 'P/E Ratio': 13.53}
# [20/502] Checking: GOOGL
#  Appending: {'Ticker': 'GOOGL', 'Company Name': 'Alphabet Inc. (Class A)', 'Start Price': 188.98, 'End Price': 178.53, 'Price Return %': -5.53, 'Q1 Dividends ($)': 0.41, 'Dividend Yield %': 0.22, 'Total Return %': -5.31, 'Volatility %': 36.28, 'Avg Daily Volume': 36619827, 'Momentum ($)': -10.45, 'ROE': 34.79, 'P/E Ratio': 20.04}
# [21/502] Checking: GOOG
#  Appending: {'Ticker': 'GOOG', 'Company Name': 'Alphabet Inc. (Class C)', 'Start Price': 190.18, 'End Price': 178.27, 'Price Return %': -6.26, 'Q1 Dividends ($)': 0.41, 'Dividend Yield %': 0.22, 'Total Return %': -6.05, 'Volatility %': 35.91, 'Avg Daily Volume': 23989043, 'Momentum ($)': -11.91, 'ROE': 34.79, 'P/E Ratio': 20.15}
# [22/502] Checking: MO
#  Appending: {'Ticker': 'MO', 'Company Name': 'Altria', 'Start Price': 50.7, 'End Price': 58.75, 'Price Return %': 15.87, 'Q1 Dividends ($)': 2.04, 'Dividend Yield %': 4.02, 'Total Return %': 19.9, 'Volatility %': 20.14, 'Avg Daily Volume': 9226102, 'Momentum ($)': 8.05, 'ROE': None, 'P/E Ratio': 10.01}
# [23/502] Checking: AMZN
#  Appending: {'Ticker': 'AMZN', 'Company Name': 'Amazon', 'Start Price': 220.22, 'End Price': 223.3, 'Price Return %': 1.4, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 1.4, 'Volatility %': 38.54, 'Avg Daily Volume': 45164155, 'Momentum ($)': 3.08, 'ROE': 25.24, 'P/E Ratio': 36.39}
# [24/502] Checking: AMCR
#  Appending: {'Ticker': 'AMCR', 'Company Name': 'Amcor', 'Start Price': 9.23, 'End Price': 9.19, 'Price Return %': -0.48, 'Q1 Dividends ($)': 0.13, 'Dividend Yield %': 1.39, 'Total Return %': 0.91, 'Volatility %': 24.48, 'Avg Daily Volume': 30636726, 'Momentum ($)': -0.04, 'ROE': 20.8, 'P/E Ratio': 17.2}
# [25/502] Checking: AEE
#  Appending: {'Ticker': 'AEE', 'Company Name': 'Ameren', 'Start Price': 87.7, 'End Price': 95.31, 'Price Return %': 8.68, 'Q1 Dividends ($)': 1.42, 'Dividend Yield %': 1.62, 'Total Return %': 10.3, 'Volatility %': 20.37, 'Avg Daily Volume': 1788315, 'Momentum ($)': 7.61, 'ROE': 10.16, 'P/E Ratio': 21.29}
# [26/502] Checking: AEP
#  Appending: {'Ticker': 'AEP', 'Company Name': 'American Electric Power', 'Start Price': 90.28, 'End Price': 102.46, 'Price Return %': 13.49, 'Q1 Dividends ($)': 1.86, 'Dividend Yield %': 2.06, 'Total Return %': 15.55, 'Volatility %': 21.47, 'Avg Daily Volume': 3673377, 'Momentum ($)': 12.18, 'ROE': 10.42, 'P/E Ratio': 20.05}
# [27/502] Checking: AXP
#  Appending: {'Ticker': 'AXP', 'Company Name': 'American Express', 'Start Price': 296.0, 'End Price': 316.39, 'Price Return %': 6.89, 'Q1 Dividends ($)': 1.52, 'Dividend Yield %': 0.51, 'Total Return %': 7.4, 'Volatility %': 38.21, 'Avg Daily Volume': 3042160, 'Momentum ($)': 20.39, 'ROE': 34.27, 'P/E Ratio': 22.93}
# [28/502] Checking: AIG
#  Appending: {'Ticker': 'AIG', 'Company Name': 'American International Group', 'Start Price': 72.25, 'End Price': 84.59, 'Price Return %': 17.08, 'Q1 Dividends ($)': 0.85, 'Dividend Yield %': 1.18, 'Total Return %': 18.26, 'Volatility %': 26.57, 'Avg Daily Volume': 4664438, 'Momentum ($)': 12.34, 'ROE': 5.74, 'P/E Ratio': 20.29}
# [29/502] Checking: AMT
#  Appending: {'Ticker': 'AMT', 'Company Name': 'American Tower', 'Start Price': 178.15, 'End Price': 217.78, 'Price Return %': 22.24, 'Q1 Dividends ($)': 3.4, 'Dividend Yield %': 1.91, 'Total Return %': 24.15, 'Volatility %': 28.43, 'Avg Daily Volume': 2751474, 'Momentum ($)': 39.63, 'ROE': 28.42, 'P/E Ratio': 35.82}
# [30/502] Checking: AWK
#  Appending: {'Ticker': 'AWK', 'Company Name': 'American Water Works', 'Start Price': 122.36, 'End Price': 137.92, 'Price Return %': 12.72, 'Q1 Dividends ($)': 1.59, 'Dividend Yield %': 1.3, 'Total Return %': 14.02, 'Volatility %': 27.68, 'Avg Daily Volume': 1438707, 'Momentum ($)': 15.56, 'ROE': 10.43, 'P/E Ratio': 25.51}
# [31/502] Checking: AMP
#  Appending: {'Ticker': 'AMP', 'Company Name': 'Ameriprise Financial', 'Start Price': 526.76, 'End Price': 528.07, 'Price Return %': 0.25, 'Q1 Dividends ($)': 3.08, 'Dividend Yield %': 0.58, 'Total Return %': 0.83, 'Volatility %': 34.48, 'Avg Daily Volume': 531359, 'Momentum ($)': 1.31, 'ROE': 58.11, 'P/E Ratio': 18.45}
# [32/502] Checking: AME
#  Appending: {'Ticker': 'AME', 'Company Name': 'Ametek', 'Start Price': 177.7, 'End Price': 180.53, 'Price Return %': 1.59, 'Q1 Dividends ($)': 0.62, 'Dividend Yield %': 0.35, 'Total Return %': 1.94, 'Volatility %': 25.09, 'Avg Daily Volume': 1381274, 'Momentum ($)': 2.83, 'ROE': 14.96, 'P/E Ratio': 30.1}
# [33/502] Checking: AMGN
#  Appending: {'Ticker': 'AMGN', 'Company Name': 'Amgen', 'Start Price': 254.95, 'End Price': 277.13, 'Price Return %': 8.7, 'Q1 Dividends ($)': 4.76, 'Dividend Yield %': 1.87, 'Total Return %': 10.57, 'Volatility %': 28.69, 'Avg Daily Volume': 3099831, 'Momentum ($)': 22.18, 'ROE': 105.67, 'P/E Ratio': 27.16}
# [34/502] Checking: APH
#  Appending: {'Ticker': 'APH', 'Company Name': 'Amphenol', 'Start Price': 68.71, 'End Price': 97.67, 'Price Return %': 42.15, 'Q1 Dividends ($)': 0.33, 'Dividend Yield %': 0.48, 'Total Return %': 42.63, 'Volatility %': 43.23, 'Avg Daily Volume': 8531150, 'Momentum ($)': 28.96, 'ROE': 27.53, 'P/E Ratio': 48.28}
# [35/502] Checking: ADI
#  Appending: {'Ticker': 'ADI', 'Company Name': 'Analog Devices', 'Start Price': 209.48, 'End Price': 236.96, 'Price Return %': 13.12, 'Q1 Dividends ($)': 1.98, 'Dividend Yield %': 0.95, 'Total Return %': 14.06, 'Volatility %': 49.67, 'Avg Daily Volume': 4111484, 'Momentum ($)': 27.48, 'ROE': 5.21, 'P/E Ratio': 66.58}
# [36/502] Checking: ANSS
#  Appending: {'Ticker': 'ANSS', 'Company Name': 'Ansys', 'Start Price': 336.06, 'End Price': 347.19, 'Price Return %': 3.31, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 3.31, 'Volatility %': 26.82, 'Avg Daily Volume': 615287, 'Momentum ($)': 11.13, 'ROE': 10.23, 'P/E Ratio': 54.68}
# [37/502] Checking: AON
#  Appending: {'Ticker': 'AON', 'Company Name': 'Aon plc', 'Start Price': 354.98, 'End Price': 352.73, 'Price Return %': -0.63, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -0.63, 'Volatility %': 24.29, 'Avg Daily Volume': 1327877, 'Momentum ($)': -2.25, 'ROE': 72.01, 'P/E Ratio': 30.66}
# [38/502] Checking: APA
#  Appending: {'Ticker': 'APA', 'Company Name': 'APA Corporation', 'Start Price': 22.76, 'End Price': 18.56, 'Price Return %': -18.45, 'Q1 Dividends ($)': 0.5, 'Dividend Yield %': 2.2, 'Total Return %': -16.26, 'Volatility %': 63.38, 'Avg Daily Volume': 8417994, 'Momentum ($)': -4.2, 'ROE': 26.18, 'P/E Ratio': 7.0}
# [39/502] Checking: APO
#  Appending: {'Ticker': 'APO', 'Company Name': 'Apollo Global Management', 'Start Price': 164.8, 'End Price': 142.92, 'Price Return %': -13.28, 'Q1 Dividends ($)': 0.97, 'Dividend Yield %': 0.59, 'Total Return %': -12.69, 'Volatility %': 51.28, 'Avg Daily Volume': 3832660, 'Momentum ($)': -21.88, 'ROE': 18.69, 'P/E Ratio': 25.17}
# [40/502] Checking: AAPL
#  Appending: {'Ticker': 'AAPL', 'Company Name': 'Apple Inc.', 'Start Price': 243.26, 'End Price': 201.08, 'Price Return %': -17.34, 'Q1 Dividends ($)': 0.51, 'Dividend Yield %': 0.21, 'Total Return %': -17.13, 'Volatility %': 41.04, 'Avg Daily Volume': 57756334, 'Momentum ($)': -42.18, 'ROE': 138.01, 'P/E Ratio': 33.21}
# [41/502] Checking: AMAT
#  Appending: {'Ticker': 'AMAT', 'Company Name': 'Applied Materials', 'Start Price': 163.03, 'End Price': 183.21, 'Price Return %': 12.38, 'Q1 Dividends ($)': 0.86, 'Dividend Yield %': 0.53, 'Total Return %': 12.91, 'Volatility %': 49.61, 'Avg Daily Volume': 7515624, 'Momentum ($)': 20.18, 'ROE': 36.37, 'P/E Ratio': 23.24}
# [42/502] Checking: APTV
#  Appending: {'Ticker': 'APTV', 'Company Name': 'Aptiv', 'Start Price': 60.3, 'End Price': 68.78, 'Price Return %': 14.06, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 14.06, 'Volatility %': 40.44, 'Avg Daily Volume': 3164388, 'Momentum ($)': 8.48, 'ROE': 15.24, 'P/E Ratio': 11.86}
# [43/502] Checking: ACGL
#  Appending: {'Ticker': 'ACGL', 'Company Name': 'Arch Capital Group', 'Start Price': 91.38, 'End Price': 90.32, 'Price Return %': -1.16, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -1.16, 'Volatility %': 28.25, 'Avg Daily Volume': 1738365, 'Momentum ($)': -1.06, 'ROE': 18.42, 'P/E Ratio': 9.15}
# [44/502] Checking: ADM
#  Appending: {'Ticker': 'ADM', 'Company Name': 'Archer Daniels Midland', 'Start Price': 49.16, 'End Price': 51.98, 'Price Return %': 5.74, 'Q1 Dividends ($)': 1.02, 'Dividend Yield %': 2.07, 'Total Return %': 7.81, 'Volatility %': 31.76, 'Avg Daily Volume': 4166479, 'Momentum ($)': 2.82, 'ROE': 5.89, 'P/E Ratio': 19.48}
# [45/502] Checking: ANET
#  Appending: {'Ticker': 'ANET', 'Company Name': 'Arista Networks', 'Start Price': 111.79, 'End Price': 99.39, 'Price Return %': -11.09, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -11.09, 'Volatility %': 66.25, 'Avg Daily Volume': 10925218, 'Momentum ($)': -12.4, 'ROE': 33.68, 'P/E Ratio': 43.26}
# [46/502] Checking: AJG
#  Appending: {'Ticker': 'AJG', 'Company Name': 'Arthur J. Gallagher & Co.', 'Start Price': 274.82, 'End Price': 317.73, 'Price Return %': 15.62, 'Q1 Dividends ($)': 1.3, 'Dividend Yield %': 0.47, 'Total Return %': 16.09, 'Volatility %': 25.91, 'Avg Daily Volume': 1568683, 'Momentum ($)': 42.91, 'ROE': 9.3, 'P/E Ratio': 49.01}
# [47/502] Checking: AIZ
#  Appending: {'Ticker': 'AIZ', 'Company Name': 'Assurant', 'Start Price': 209.8, 'End Price': 196.84, 'Price Return %': -6.18, 'Q1 Dividends ($)': 1.6, 'Dividend Yield %': 0.76, 'Total Return %': -5.41, 'Volatility %': 28.76, 'Avg Daily Volume': 512242, 'Momentum ($)': -12.96, 'ROE': 13.2, 'P/E Ratio': 15.08}
# [48/502] Checking: T
#  Appending: {'Ticker': 'T', 'Company Name': 'AT&T', 'Start Price': 22.31, 'End Price': 28.08, 'Price Return %': 25.88, 'Q1 Dividends ($)': 0.56, 'Dividend Yield %': 2.49, 'Total Return %': 28.37, 'Volatility %': 25.47, 'Avg Daily Volume': 38879477, 'Momentum ($)': 5.77, 'ROE': 10.88, 'P/E Ratio': 17.4}
# [49/502] Checking: ATO
#  Appending: {'Ticker': 'ATO', 'Company Name': 'Atmos Energy', 'Start Price': 136.73, 'End Price': 152.49, 'Price Return %': 11.53, 'Q1 Dividends ($)': 1.74, 'Dividend Yield %': 1.27, 'Total Return %': 12.8, 'Volatility %': 19.51, 'Avg Daily Volume': 1028156, 'Momentum ($)': 15.76, 'ROE': 9.19, 'P/E Ratio': 21.27}
# [50/502] Checking: ADSK
#  Appending: {'Ticker': 'ADSK', 'Company Name': 'Autodesk', 'Start Price': 293.32, 'End Price': 305.13, 'Price Return %': 4.03, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 4.03, 'Volatility %': 29.17, 'Avg Daily Volume': 1586398, 'Momentum ($)': 11.81, 'ROE': 42.36, 'P/E Ratio': 68.1}
# [51/502] Checking: ADP
#  Appending: {'Ticker': 'ADP', 'Company Name': 'Automatic Data Processing', 'Start Price': 286.68, 'End Price': 303.45, 'Price Return %': 5.85, 'Q1 Dividends ($)': 3.08, 'Dividend Yield %': 1.07, 'Total Return %': 6.92, 'Volatility %': 22.19, 'Avg Daily Volume': 1812521, 'Momentum ($)': 16.77, 'ROE': 76.29, 'P/E Ratio': 31.65}
# [52/502] Checking: AZO
#  Appending: {'Ticker': 'AZO', 'Company Name': 'AutoZone', 'Start Price': 3250.0, 'End Price': 3609.49, 'Price Return %': 11.06, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 11.06, 'Volatility %': 23.03, 'Avg Daily Volume': 136318, 'Momentum ($)': 359.49, 'ROE': None, 'P/E Ratio': 25.51}
# [53/502] Checking: AVB
#  Appending: {'Ticker': 'AVB', 'Company Name': 'AvalonBay Communities', 'Start Price': 213.45, 'End Price': 202.63, 'Price Return %': -5.07, 'Q1 Dividends ($)': 3.5, 'Dividend Yield %': 1.64, 'Total Return %': -3.43, 'Volatility %': 25.43, 'Avg Daily Volume': 807813, 'Momentum ($)': -10.82, 'ROE': 9.69, 'P/E Ratio': 25.2}
# [54/502] Checking: AVY
#  Appending: {'Ticker': 'AVY', 'Company Name': 'Avery Dennison', 'Start Price': 181.47, 'End Price': 175.63, 'Price Return %': -3.22, 'Q1 Dividends ($)': 1.82, 'Dividend Yield %': 1.0, 'Total Return %': -2.21, 'Volatility %': 26.05, 'Avg Daily Volume': 781187, 'Momentum ($)': -5.84, 'ROE': 31.95, 'P/E Ratio': 21.09}
# [55/502] Checking: AXON
#  Appending: {'Ticker': 'AXON', 'Company Name': 'Axon Enterprise', 'Start Price': 596.49, 'End Price': 818.6, 'Price Return %': 37.24, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 37.24, 'Volatility %': 57.95, 'Avg Daily Volume': 712836, 'Momentum ($)': 222.11, 'ROE': 15.17, 'P/E Ratio': 192.14}
# [56/502] Checking: BKR
#  Appending: {'Ticker': 'BKR', 'Company Name': 'Baker Hughes', 'Start Price': 41.1, 'End Price': 38.06, 'Price Return %': -7.4, 'Q1 Dividends ($)': 0.46, 'Dividend Yield %': 1.12, 'Total Return %': -6.28, 'Volatility %': 40.49, 'Avg Daily Volume': 8033593, 'Momentum ($)': -3.04, 'ROE': 18.04, 'P/E Ratio': 13.53}
# [57/502] Checking: BALL
#  Appending: {'Ticker': 'BALL', 'Company Name': 'Ball Corporation', 'Start Price': 54.03, 'End Price': 56.41, 'Price Return %': 4.4, 'Q1 Dividends ($)': 0.4, 'Dividend Yield %': 0.74, 'Total Return %': 5.14, 'Volatility %': 28.53, 'Avg Daily Volume': 2753598, 'Momentum ($)': 2.38, 'ROE': 8.22, 'P/E Ratio': 33.37}
# [58/502] Checking: BAC
#  Appending: {'Ticker': 'BAC', 'Company Name': 'Bank of America', 'Start Price': 43.75, 'End Price': 47.12, 'Price Return %': 7.69, 'Q1 Dividends ($)': 0.52, 'Dividend Yield %': 1.19, 'Total Return %': 8.88, 'Volatility %': 32.91, 'Avg Daily Volume': 43273786, 'Momentum ($)': 3.37, 'ROE': 9.46, 'P/E Ratio': 14.61}
# [59/502] Checking: BAX
#  Appending: {'Ticker': 'BAX', 'Company Name': 'Baxter International', 'Start Price': 28.96, 'End Price': 30.39, 'Price Return %': 4.95, 'Q1 Dividends ($)': 0.34, 'Dividend Yield %': 1.17, 'Total Return %': 6.12, 'Volatility %': 37.69, 'Avg Daily Volume': 4485273, 'Momentum ($)': 1.43, 'ROE': -3.51, 'P/E Ratio': None}
# [60/502] Checking: BDX
#  Appending: {'Ticker': 'BDX', 'Company Name': 'Becton Dickinson', 'Start Price': 224.11, 'End Price': 170.86, 'Price Return %': -23.76, 'Q1 Dividends ($)': 2.08, 'Dividend Yield %': 0.93, 'Total Return %': -22.83, 'Volatility %': 35.91, 'Avg Daily Volume': 2582570, 'Momentum ($)': -53.25, 'ROE': 5.89, 'P/E Ratio': 34.14}
# [61/502] Checking: BRK-B
#  Appending: {'Ticker': 'BRK-B', 'Company Name': '', 'Start Price': 451.1, 'End Price': 485.68, 'Price Return %': 7.67, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 7.67, 'Volatility %': 22.97, 'Avg Daily Volume': 4930227, 'Momentum ($)': 34.58, 'ROE': 13.19, 'P/E Ratio': 12.92}
# [62/502] Checking: BBY
#  Appending: {'Ticker': 'BBY', 'Company Name': 'Best Buy', 'Start Price': 83.92, 'End Price': 68.22, 'Price Return %': -18.71, 'Q1 Dividends ($)': 1.9, 'Dividend Yield %': 2.26, 'Total Return %': -16.45, 'Volatility %': 52.36, 'Avg Daily Volume': 3716266, 'Momentum ($)': -15.7, 'ROE': 30.21, 'P/E Ratio': 17.59}
# [63/502] Checking: TECH
#  Appending: {'Ticker': 'TECH', 'Company Name': 'Bio-Techne', 'Start Price': 71.28, 'End Price': 51.84, 'Price Return %': -27.27, 'Q1 Dividends ($)': 0.16, 'Dividend Yield %': 0.22, 'Total Return %': -27.05, 'Volatility %': 45.57, 'Avg Daily Volume': 2020679, 'Momentum ($)': -19.44, 'ROE': 6.53, 'P/E Ratio': 64.02}
# [64/502] Checking: BIIB
#  Appending: {'Ticker': 'BIIB', 'Company Name': 'Biogen', 'Start Price': 150.0, 'End Price': 126.08, 'Price Return %': -15.95, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -15.95, 'Volatility %': 32.69, 'Avg Daily Volume': 1608004, 'Momentum ($)': -23.92, 'ROE': 9.19, 'P/E Ratio': 13.13}
# [65/502] Checking: BLK
#  Appending: {'Ticker': 'BLK', 'Company Name': 'BlackRock', 'Start Price': 1006.55, 'End Price': 1047.82, 'Price Return %': 4.1, 'Q1 Dividends ($)': 10.42, 'Dividend Yield %': 1.04, 'Total Return %': 5.14, 'Volatility %': 32.75, 'Avg Daily Volume': 812444, 'Momentum ($)': 41.27, 'ROE': 13.93, 'P/E Ratio': 26.32}
# [66/502] Checking: BX
#  Appending: {'Ticker': 'BX', 'Company Name': 'Blackstone Inc.', 'Start Price': 171.07, 'End Price': 151.11, 'Price Return %': -11.67, 'Q1 Dividends ($)': 2.37, 'Dividend Yield %': 1.39, 'Total Return %': -10.28, 'Volatility %': 46.65, 'Avg Daily Volume': 4352306, 'Momentum ($)': -19.96, 'ROE': 26.35, 'P/E Ratio': 47.01}
# [67/502] Checking: BK
#  Appending: {'Ticker': 'BK', 'Company Name': 'BNY Mellon', 'Start Price': 76.51, 'End Price': 91.18, 'Price Return %': 19.17, 'Q1 Dividends ($)': 0.94, 'Dividend Yield %': 1.23, 'Total Return %': 20.4, 'Volatility %': 29.72, 'Avg Daily Volume': 4274336, 'Momentum ($)': 14.67, 'ROE': 11.23, 'P/E Ratio': 15.08}
# [68/502] Checking: BA
#  Appending: {'Ticker': 'BA', 'Company Name': 'Boeing', 'Start Price': 171.87, 'End Price': 214.55, 'Price Return %': 24.83, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 24.83, 'Volatility %': 44.86, 'Avg Daily Volume': 8791743, 'Momentum ($)': 42.68, 'ROE': None, 'P/E Ratio': None}
# [69/502] Checking: BKNG
#  Appending: {'Ticker': 'BKNG', 'Company Name': 'Booking Holdings', 'Start Price': 4906.75, 'End Price': 5693.13, 'Price Return %': 16.03, 'Q1 Dividends ($)': 19.2, 'Dividend Yield %': 0.39, 'Total Return %': 16.42, 'Volatility %': 32.58, 'Avg Daily Volume': 266037, 'Momentum ($)': 786.38, 'ROE': None, 'P/E Ratio': 35.59}
# [70/502] Checking: BSX
#  Appending: {'Ticker': 'BSX', 'Company Name': 'Boston Scientific', 'Start Price': 89.38, 'End Price': 106.53, 'Price Return %': 19.19, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 19.19, 'Volatility %': 27.46, 'Avg Daily Volume': 7746624, 'Momentum ($)': 17.15, 'ROE': 9.5, 'P/E Ratio': 76.15}
# [71/502] Checking: BMY
#  Appending: {'Ticker': 'BMY', 'Company Name': 'Bristol Myers Squibb', 'Start Price': 54.84, 'End Price': 45.75, 'Price Return %': -16.59, 'Q1 Dividends ($)': 1.24, 'Dividend Yield %': 2.26, 'Total Return %': -14.33, 'Volatility %': 29.54, 'Avg Daily Volume': 13513196, 'Momentum ($)': -9.1, 'ROE': 31.99, 'P/E Ratio': 17.51}
# [72/502] Checking: AVGO
#  Appending: {'Ticker': 'AVGO', 'Company Name': 'Broadcom', 'Start Price': 230.74, 'End Price': 269.35, 'Price Return %': 16.73, 'Q1 Dividends ($)': 1.18, 'Dividend Yield %': 0.51, 'Total Return %': 17.25, 'Volatility %': 60.46, 'Avg Daily Volume': 28718315, 'Momentum ($)': 38.61, 'ROE': 18.98, 'P/E Ratio': 100.07}
# [73/502] Checking: BR
#  Appending: {'Ticker': 'BR', 'Company Name': 'Broadridge Financial Solutions', 'Start Price': 225.12, 'End Price': 239.45, 'Price Return %': 6.37, 'Q1 Dividends ($)': 1.76, 'Dividend Yield %': 0.78, 'Total Return %': 7.15, 'Volatility %': 24.11, 'Avg Daily Volume': 533322, 'Momentum ($)': 14.33, 'ROE': 33.92, 'P/E Ratio': 36.36}
# [74/502] Checking: BRO
#  Appending: {'Ticker': 'BRO', 'Company Name': 'Brown & Brown', 'Start Price': 100.26, 'End Price': 109.58, 'Price Return %': 9.29, 'Q1 Dividends ($)': 0.3, 'Dividend Yield %': 0.3, 'Total Return %': 9.59, 'Volatility %': 24.05, 'Avg Daily Volume': 2254927, 'Momentum ($)': 9.32, 'ROE': 16.52, 'P/E Ratio': 30.28}
# [75/502] Checking: BF-B
#  Appending: {'Ticker': 'BF-B', 'Company Name': '', 'Start Price': 36.65, 'End Price': 26.46, 'Price Return %': -27.8, 'Q1 Dividends ($)': 0.45, 'Dividend Yield %': 1.24, 'Total Return %': -26.56, 'Volatility %': 43.74, 'Avg Daily Volume': 3863914, 'Momentum ($)': -10.19, 'ROE': 23.14, 'P/E Ratio': 15.36}
# [76/502] Checking: BLDR
#  Appending: {'Ticker': 'BLDR', 'Company Name': 'Builders FirstSource', 'Start Price': 141.98, 'End Price': 117.01, 'Price Return %': -17.59, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -17.59, 'Volatility %': 46.85, 'Avg Daily Volume': 1885983, 'Momentum ($)': -24.97, 'ROE': 19.62, 'P/E Ratio': 16.31}
# [77/502] Checking: BG
#  Appending: {'Ticker': 'BG', 'Company Name': 'Bunge Global', 'Start Price': 76.16, 'End Price': 80.44, 'Price Return %': 5.62, 'Q1 Dividends ($)': 1.38, 'Dividend Yield %': 1.81, 'Total Return %': 7.43, 'Volatility %': 32.1, 'Avg Daily Volume': 1785226, 'Momentum ($)': 4.28, 'ROE': 9.86, 'P/E Ratio': 10.07}
# [78/502] Checking: BXP
#  Appending: {'Ticker': 'BXP', 'Company Name': 'BXP, Inc.', 'Start Price': 71.6, 'End Price': 67.62, 'Price Return %': -5.55, 'Q1 Dividends ($)': 1.96, 'Dividend Yield %': 2.74, 'Total Return %': -2.81, 'Volatility %': 35.46, 'Avg Daily Volume': 1528309, 'Momentum ($)': -3.98, 'ROE': 0.8, 'P/E Ratio': None}
# [79/502] Checking: CHRW
#  Appending: {'Ticker': 'CHRW', 'Company Name': 'C.H. Robinson', 'Start Price': 101.47, 'End Price': 96.66, 'Price Return %': -4.74, 'Q1 Dividends ($)': 1.24, 'Dividend Yield %': 1.22, 'Total Return %': -3.52, 'Volatility %': 30.73, 'Avg Daily Volume': 1326193, 'Momentum ($)': -4.81, 'ROE': 32.11, 'P/E Ratio': 23.4}
# [80/502] Checking: CDNS
#  Appending: {'Ticker': 'CDNS', 'Company Name': 'Cadence Design Systems', 'Start Price': 297.66, 'End Price': 305.2, 'Price Return %': 2.53, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 2.53, 'Volatility %': 45.15, 'Avg Daily Volume': 2132499, 'Momentum ($)': 7.54, 'ROE': 25.92, 'P/E Ratio': 82.74}
# [81/502] Checking: CZR
#  Appending: {'Ticker': 'CZR', 'Company Name': 'Caesars Entertainment', 'Start Price': 32.59, 'End Price': 28.86, 'Price Return %': -11.45, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -11.45, 'Volatility %': 53.7, 'Avg Daily Volume': 5448623, 'Momentum ($)': -3.73, 'ROE': -3.77, 'P/E Ratio': None}
# [82/502] Checking: CPT
#  Appending: {'Ticker': 'CPT', 'Company Name': 'Camden Property Trust', 'Start Price': 112.65, 'End Price': 112.71, 'Price Return %': 0.06, 'Q1 Dividends ($)': 2.1, 'Dividend Yield %': 1.86, 'Total Return %': 1.92, 'Volatility %': 25.19, 'Avg Daily Volume': 992634, 'Momentum ($)': 0.06, 'ROE': 2.6, 'P/E Ratio': 104.6}
# [83/502] Checking: CPB
#  Appending: {'Ticker': 'CPB', 'Company Name': "Campbell's Company (The)", 'Start Price': 41.11, 'End Price': 30.41, 'Price Return %': -26.01, 'Q1 Dividends ($)': 0.78, 'Dividend Yield %': 1.9, 'Total Return %': -24.11, 'Volatility %': 27.73, 'Avg Daily Volume': 3715752, 'Momentum ($)': -10.69, 'ROE': 11.66, 'P/E Ratio': 20.83}
# [84/502] Checking: COF
#  Appending: {'Ticker': 'COF', 'Company Name': 'Capital One', 'Start Price': 177.61, 'End Price': 211.01, 'Price Return %': 18.8, 'Q1 Dividends ($)': 1.2, 'Dividend Yield %': 0.68, 'Total Return %': 19.48, 'Volatility %': 45.53, 'Avg Daily Volume': 4634571, 'Momentum ($)': 33.4, 'ROE': 8.03, 'P/E Ratio': 18.55}
# [85/502] Checking: CAH
#  Appending: {'Ticker': 'CAH', 'Company Name': 'Cardinal Health', 'Start Price': 117.23, 'End Price': 166.67, 'Price Return %': 42.18, 'Q1 Dividends ($)': 1.01, 'Dividend Yield %': 0.86, 'Total Return %': 43.04, 'Volatility %': 22.4, 'Avg Daily Volume': 2481327, 'Momentum ($)': 49.44, 'ROE': None, 'P/E Ratio': 25.85}
# [86/502] Checking: KMX
#  Appending: {'Ticker': 'KMX', 'Company Name': 'CarMax', 'Start Price': 81.22, 'End Price': 66.6, 'Price Return %': -18.0, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -18.0, 'Volatility %': 44.41, 'Avg Daily Volume': 2959107, 'Momentum ($)': -14.62, 'ROE': 8.97, 'P/E Ratio': 19.51}
# [87/502] Checking: CCL
#  Appending: {'Ticker': 'CCL', 'Company Name': 'Carnival', 'Start Price': 25.01, 'End Price': 27.26, 'Price Return %': 9.0, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 9.0, 'Volatility %': 57.31, 'Avg Daily Volume': 24880928, 'Momentum ($)': 2.25, 'ROE': 30.02, 'P/E Ratio': 15.69}
# [88/502] Checking: CARR
#  Appending: {'Ticker': 'CARR', 'Company Name': 'Carrier Global', 'Start Price': 68.11, 'End Price': 73.67, 'Price Return %': 8.16, 'Q1 Dividends ($)': 0.22, 'Dividend Yield %': 0.33, 'Total Return %': 8.49, 'Volatility %': 37.21, 'Avg Daily Volume': 5475714, 'Momentum ($)': 5.56, 'ROE': 11.12, 'P/E Ratio': 50.43}
# [89/502] Checking: CAT
#  Appending: {'Ticker': 'CAT', 'Company Name': 'Caterpillar Inc.', 'Start Price': 356.74, 'End Price': 384.71, 'Price Return %': 7.84, 'Q1 Dividends ($)': 2.82, 'Dividend Yield %': 0.79, 'Total Return %': 8.63, 'Volatility %': 33.93, 'Avg Daily Volume': 2711492, 'Momentum ($)': 27.97, 'ROE': 55.65, 'P/E Ratio': 19.42}
# [90/502] Checking: CBOE
#  Appending: {'Ticker': 'CBOE', 'Company Name': 'Cboe Global Markets', 'Start Price': 196.44, 'End Price': 229.0, 'Price Return %': 16.58, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 16.58, 'Volatility %': 24.35, 'Avg Daily Volume': 870775, 'Momentum ($)': 32.56, 'ROE': 19.02, 'P/E Ratio': 30.4}
# [91/502] Checking: CBRE
#  Appending: {'Ticker': 'CBRE', 'Company Name': 'CBRE Group', 'Start Price': 129.9, 'End Price': 139.38, 'Price Return %': 7.3, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 7.3, 'Volatility %': 34.35, 'Avg Daily Volume': 1899442, 'Momentum ($)': 9.48, 'ROE': 11.92, 'P/E Ratio': 43.92}
# [92/502] Checking: CDW
#  Appending: {'Ticker': 'CDW', 'Company Name': 'CDW Corporation', 'Start Price': 168.88, 'End Price': 177.41, 'Price Return %': 5.05, 'Q1 Dividends ($)': 1.25, 'Dividend Yield %': 0.74, 'Total Return %': 5.79, 'Volatility %': 35.91, 'Avg Daily Volume': 1416422, 'Momentum ($)': 8.53, 'ROE': 48.71, 'P/E Ratio': 22.57}
# [93/502] Checking: COR
#  Appending: {'Ticker': 'COR', 'Company Name': 'Cencora', 'Start Price': 223.8, 'End Price': 299.42, 'Price Return %': 33.79, 'Q1 Dividends ($)': 1.1, 'Dividend Yield %': 0.49, 'Total Return %': 34.28, 'Volatility %': 22.19, 'Avg Daily Volume': 1675704, 'Momentum ($)': 75.62, 'ROE': 141.78, 'P/E Ratio': 34.25}
# [94/502] Checking: CNC
#  Appending: {'Ticker': 'CNC', 'Company Name': 'Centene Corporation', 'Start Price': 60.51, 'End Price': 53.99, 'Price Return %': -10.78, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -10.78, 'Volatility %': 33.52, 'Avg Daily Volume': 4793168, 'Momentum ($)': -6.52, 'ROE': 12.53, 'P/E Ratio': 4.91}
# [95/502] Checking: CNP
#  Appending: {'Ticker': 'CNP', 'Company Name': 'CenterPoint Energy', 'Start Price': 31.1, 'End Price': 36.37, 'Price Return %': 16.95, 'Q1 Dividends ($)': 0.44, 'Dividend Yield %': 1.41, 'Total Return %': 18.37, 'Volatility %': 18.04, 'Avg Daily Volume': 5290818, 'Momentum ($)': 5.27, 'ROE': 9.22, 'P/E Ratio': 24.28}
# [96/502] Checking: CF
#  Appending: {'Ticker': 'CF', 'Company Name': 'CF Industries', 'Start Price': 84.81, 'End Price': 90.99, 'Price Return %': 7.29, 'Q1 Dividends ($)': 1.0, 'Dividend Yield %': 1.18, 'Total Return %': 8.47, 'Volatility %': 37.23, 'Avg Daily Volume': 2822312, 'Momentum ($)': 6.18, 'ROE': 20.79, 'P/E Ratio': 12.52}
# [97/502] Checking: CRL
#  Appending: {'Ticker': 'CRL', 'Company Name': 'Charles River Laboratories', 'Start Price': 182.64, 'End Price': 150.01, 'Price Return %': -17.87, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -17.87, 'Volatility %': 65.88, 'Avg Daily Volume': 1385575, 'Momentum ($)': -32.63, 'ROE': -0.67, 'P/E Ratio': None}
# [98/502] Checking: SCHW
#  Appending: {'Ticker': 'SCHW', 'Company Name': 'Charles Schwab Corporation', 'Start Price': 73.36, 'End Price': 89.98, 'Price Return %': 22.66, 'Q1 Dividends ($)': 0.54, 'Dividend Yield %': 0.74, 'Total Return %': 23.39, 'Volatility %': 29.3, 'Avg Daily Volume': 10471292, 'Momentum ($)': 16.62, 'ROE': 14.12, 'P/E Ratio': 27.72}
# [99/502] Checking: CHTR
#  Appending: {'Ticker': 'CHTR', 'Company Name': 'Charter Communications', 'Start Price': 349.35, 'End Price': 400.97, 'Price Return %': 14.78, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 14.78, 'Volatility %': 37.73, 'Avg Daily Volume': 1305969, 'Momentum ($)': 51.62, 'ROE': 33.12, 'P/E Ratio': 11.64}
# [100/502] Checking: CVX
#  Appending: {'Ticker': 'CVX', 'Company Name': 'Chevron Corporation', 'Start Price': 143.35, 'End Price': 143.79, 'Price Return %': 0.3, 'Q1 Dividends ($)': 3.42, 'Dividend Yield %': 2.39, 'Total Return %': 2.69, 'Volatility %': 29.57, 'Avg Daily Volume': 9026432, 'Momentum ($)': 0.44, 'ROE': 10.08, 'P/E Ratio': 16.96}
# [101/502] Checking: CMG
#  Appending: {'Ticker': 'CMG', 'Company Name': 'Chipotle Mexican Grill', 'Start Price': 59.89, 'End Price': 55.05, 'Price Return %': -8.08, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -8.08, 'Volatility %': 34.64, 'Avg Daily Volume': 12851021, 'Momentum ($)': -4.84, 'ROE': 45.57, 'P/E Ratio': 50.5}
# [102/502] Checking: CB
#  Appending: {'Ticker': 'CB', 'Company Name': 'Chubb Limited', 'Start Price': 271.66, 'End Price': 285.12, 'Price Return %': 4.95, 'Q1 Dividends ($)': 0.91, 'Dividend Yield %': 0.33, 'Total Return %': 5.29, 'Volatility %': 23.44, 'Avg Daily Volume': 1745848, 'Momentum ($)': 13.46, 'ROE': 12.86, 'P/E Ratio': 13.66}
# [103/502] Checking: CHD
#  Appending: {'Ticker': 'CHD', 'Company Name': 'Church & Dwight', 'Start Price': 103.23, 'End Price': 94.78, 'Price Return %': -8.18, 'Q1 Dividends ($)': 0.59, 'Dividend Yield %': 0.57, 'Total Return %': -7.61, 'Volatility %': 23.6, 'Avg Daily Volume': 2027761, 'Momentum ($)': -8.45, 'ROE': 13.35, 'P/E Ratio': 42.24}
# [104/502] Checking: CI
#  Appending: {'Ticker': 'CI', 'Company Name': 'Cigna', 'Start Price': 271.84, 'End Price': 326.31, 'Price Return %': 20.04, 'Q1 Dividends ($)': 3.02, 'Dividend Yield %': 1.11, 'Total Return %': 21.15, 'Volatility %': 27.58, 'Avg Daily Volume': 1824077, 'Momentum ($)': 54.47, 'ROE': 13.21, 'P/E Ratio': 17.82}
# [105/502] Checking: CINF
#  Appending: {'Ticker': 'CINF', 'Company Name': 'Cincinnati Financial', 'Start Price': 140.78, 'End Price': 146.23, 'Price Return %': 3.87, 'Q1 Dividends ($)': 1.74, 'Dividend Yield %': 1.24, 'Total Return %': 5.11, 'Volatility %': 28.4, 'Avg Daily Volume': 727346, 'Momentum ($)': 5.45, 'ROE': 10.97, 'P/E Ratio': 16.19}
# [106/502] Checking: CTAS
#  Appending: {'Ticker': 'CTAS', 'Company Name': 'Cintas', 'Start Price': 181.41, 'End Price': 220.75, 'Price Return %': 21.68, 'Q1 Dividends ($)': 0.78, 'Dividend Yield %': 0.43, 'Total Return %': 22.11, 'Volatility %': 24.73, 'Avg Daily Volume': 1757017, 'Momentum ($)': 39.34, 'ROE': 40.3, 'P/E Ratio': 50.9}
# [107/502] Checking: CSCO
#  Appending: {'Ticker': 'CSCO', 'Company Name': 'Cisco', 'Start Price': 57.96, 'End Price': 68.24, 'Price Return %': 17.73, 'Q1 Dividends ($)': 0.81, 'Dividend Yield %': 1.4, 'Total Return %': 19.13, 'Volatility %': 26.83, 'Avg Daily Volume': 21887069, 'Momentum ($)': 10.28, 'ROE': 21.36, 'P/E Ratio': 28.31}
# [108/502] Checking: C
#  Appending: {'Ticker': 'C', 'Company Name': 'Citigroup', 'Start Price': 68.91, 'End Price': 84.38, 'Price Return %': 22.45, 'Q1 Dividends ($)': 1.12, 'Dividend Yield %': 1.63, 'Total Return %': 24.08, 'Volatility %': 38.63, 'Avg Daily Volume': 15840969, 'Momentum ($)': 15.47, 'ROE': 6.44, 'P/E Ratio': 14.02}
# [109/502] Checking: CFG
#  Appending: {'Ticker': 'CFG', 'Company Name': 'Citizens Financial Group', 'Start Price': 42.74, 'End Price': 44.43, 'Price Return %': 3.96, 'Q1 Dividends ($)': 0.84, 'Dividend Yield %': 1.97, 'Total Return %': 5.92, 'Volatility %': 38.31, 'Avg Daily Volume': 4737883, 'Momentum ($)': 1.69, 'ROE': 6.37, 'P/E Ratio': 15.15}
# [110/502] Checking: CLX
#  Appending: {'Ticker': 'CLX', 'Company Name': 'Clorox', 'Start Price': 159.21, 'End Price': 119.14, 'Price Return %': -25.17, 'Q1 Dividends ($)': 2.44, 'Dividend Yield %': 1.53, 'Total Return %': -23.64, 'Volatility %': 24.45, 'Avg Daily Volume': 1589982, 'Momentum ($)': -40.07, 'ROE': 318.65, 'P/E Ratio': 22.41}
# [111/502] Checking: CME
#  Appending: {'Ticker': 'CME', 'Company Name': 'CME Group', 'Start Price': 230.52, 'End Price': 274.76, 'Price Return %': 19.19, 'Q1 Dividends ($)': 2.5, 'Dividend Yield %': 1.08, 'Total Return %': 20.28, 'Volatility %': 20.42, 'Avg Daily Volume': 2417013, 'Momentum ($)': 44.24, 'ROE': 13.39, 'P/E Ratio': 27.87}
# [112/502] Checking: CMS
#  Appending: {'Ticker': 'CMS', 'Company Name': 'CMS Energy', 'Start Price': 65.52, 'End Price': 69.01, 'Price Return %': 5.33, 'Q1 Dividends ($)': 1.09, 'Dividend Yield %': 1.66, 'Total Return %': 6.99, 'Volatility %': 19.79, 'Avg Daily Volume': 2562926, 'Momentum ($)': 3.49, 'ROE': 11.23, 'P/E Ratio': 20.85}
# [113/502] Checking: KO
#  Appending: {'Ticker': 'KO', 'Company Name': 'Coca-Cola Company (The)', 'Start Price': 60.95, 'End Price': 70.33, 'Price Return %': 15.38, 'Q1 Dividends ($)': 1.02, 'Dividend Yield %': 1.67, 'Total Return %': 17.06, 'Volatility %': 20.0, 'Avg Daily Volume': 17485657, 'Momentum ($)': 9.38, 'ROE': 38.78, 'P/E Ratio': 28.65}
# [114/502] Checking: CTSH
#  Appending: {'Ticker': 'CTSH', 'Company Name': 'Cognizant', 'Start Price': 75.86, 'End Price': 77.74, 'Price Return %': 2.48, 'Q1 Dividends ($)': 0.62, 'Dividend Yield %': 0.82, 'Total Return %': 3.3, 'Volatility %': 28.42, 'Avg Daily Volume': 3846722, 'Momentum ($)': 1.88, 'ROE': 16.61, 'P/E Ratio': 17.05}
# [115/502] Checking: COIN
#  Appending: {'Ticker': 'COIN', 'Company Name': 'Coinbase', 'Start Price': 257.21, 'End Price': 353.43, 'Price Return %': 37.41, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 37.41, 'Volatility %': 84.74, 'Avg Daily Volume': 11099468, 'Momentum ($)': 96.22, 'ROE': 15.84, 'P/E Ratio': 66.63}
# [116/502] Checking: CL
#  Appending: {'Ticker': 'CL', 'Company Name': 'Colgate-Palmolive', 'Start Price': 89.54, 'End Price': 88.71, 'Price Return %': -0.93, 'Q1 Dividends ($)': 1.02, 'Dividend Yield %': 1.14, 'Total Return %': 0.21, 'Volatility %': 23.98, 'Avg Daily Volume': 5337644, 'Momentum ($)': -0.83, 'ROE': 451.26, 'P/E Ratio': 26.28}
# [117/502] Checking: CMCSA
#  Appending: {'Ticker': 'CMCSA', 'Company Name': 'Comcast', 'Start Price': 36.44, 'End Price': 35.0, 'Price Return %': -3.96, 'Q1 Dividends ($)': 0.64, 'Dividend Yield %': 1.76, 'Total Return %': -2.2, 'Volatility %': 30.11, 'Avg Daily Volume': 25373596, 'Momentum ($)': -1.44, 'ROE': 18.05, 'P/E Ratio': 8.86}
# [118/502] Checking: CAG
#  Appending: {'Ticker': 'CAG', 'Company Name': 'Conagra Brands', 'Start Price': 26.9, 'End Price': 20.4, 'Price Return %': -24.17, 'Q1 Dividends ($)': 0.7, 'Dividend Yield %': 2.6, 'Total Return %': -21.57, 'Volatility %': 26.45, 'Avg Daily Volume': 6551567, 'Momentum ($)': -6.5, 'ROE': 3.66, 'P/E Ratio': 30.87}
# [119/502] Checking: COP
#  Appending: {'Ticker': 'COP', 'Company Name': 'ConocoPhillips', 'Start Price': 98.44, 'End Price': 90.17, 'Price Return %': -8.4, 'Q1 Dividends ($)': 1.56, 'Dividend Yield %': 1.58, 'Total Return %': -6.81, 'Volatility %': 40.6, 'Avg Daily Volume': 8580760, 'Momentum ($)': -8.27, 'ROE': 16.66, 'P/E Ratio': 11.87}
# [120/502] Checking: ED
#  Appending: {'Ticker': 'ED', 'Company Name': 'Consolidated Edison', 'Start Price': 87.49, 'End Price': 98.15, 'Price Return %': 12.18, 'Q1 Dividends ($)': 1.7, 'Dividend Yield %': 1.94, 'Total Return %': 14.12, 'Volatility %': 23.59, 'Avg Daily Volume': 2884616, 'Momentum ($)': 10.66, 'ROE': 8.33, 'P/E Ratio': 18.54}
# [121/502] Checking: STZ
#  Appending: {'Ticker': 'STZ', 'Company Name': 'Constellation Brands', 'Start Price': 220.04, 'End Price': 161.33, 'Price Return %': -26.68, 'Q1 Dividends ($)': 2.03, 'Dividend Yield %': 0.92, 'Total Return %': -25.76, 'Volatility %': 36.47, 'Avg Daily Volume': 2510623, 'Momentum ($)': -58.71, 'ROE': -0.36, 'P/E Ratio': None}
# [122/502] Checking: CEG
#  Appending: {'Ticker': 'CEG', 'Company Name': 'Constellation Energy', 'Start Price': 241.82, 'End Price': 320.17, 'Price Return %': 32.4, 'Q1 Dividends ($)': 0.78, 'Dividend Yield %': 0.32, 'Total Return %': 32.72, 'Volatility %': 78.35, 'Avg Daily Volume': 4161270, 'Momentum ($)': 78.35, 'ROE': 23.97, 'P/E Ratio': 32.9}
# [123/502] Checking: COO
#  Appending: {'Ticker': 'COO', 'Company Name': 'Cooper Companies (The)', 'Start Price': 90.66, 'End Price': 71.14, 'Price Return %': -21.53, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -21.53, 'Volatility %': 39.65, 'Avg Daily Volume': 2171968, 'Momentum ($)': -19.52, 'ROE': 5.15, 'P/E Ratio': 35.41}
# [124/502] Checking: CPRT
#  Appending: {'Ticker': 'CPRT', 'Company Name': 'Copart', 'Start Price': 56.32, 'End Price': 48.18, 'Price Return %': -14.45, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -14.45, 'Volatility %': 27.43, 'Avg Daily Volume': 5458876, 'Momentum ($)': -8.14, 'ROE': 18.44, 'P/E Ratio': 32.66}
# [125/502] Checking: GLW
#  Appending: {'Ticker': 'GLW', 'Company Name': 'Corning Inc.', 'Start Price': 46.18, 'End Price': 51.82, 'Price Return %': 12.21, 'Q1 Dividends ($)': 0.56, 'Dividend Yield %': 1.21, 'Total Return %': 13.42, 'Volatility %': 37.69, 'Avg Daily Volume': 5792212, 'Momentum ($)': 5.64, 'ROE': 4.87, 'P/E Ratio': 102.0}
# [126/502] Checking: CPAY
#  Appending: {'Ticker': 'CPAY', 'Company Name': 'Corpay', 'Start Price': 339.93, 'End Price': 327.04, 'Price Return %': -3.79, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -3.79, 'Volatility %': 43.8, 'Avg Daily Volume': 494295, 'Momentum ($)': -12.89, 'ROE': 30.04, 'P/E Ratio': 23.81}
# [127/502] Checking: CTVA
#  Appending: {'Ticker': 'CTVA', 'Company Name': 'Corteva', 'Start Price': 56.05, 'End Price': 74.39, 'Price Return %': 32.71, 'Q1 Dividends ($)': 0.34, 'Dividend Yield %': 0.61, 'Total Return %': 33.32, 'Volatility %': 27.61, 'Avg Daily Volume': 3772357, 'Momentum ($)': 18.34, 'ROE': 4.66, 'P/E Ratio': 46.46}
# [128/502] Checking: CSGP
#  Appending: {'Ticker': 'CSGP', 'Company Name': 'CoStar Group', 'Start Price': 70.83, 'End Price': 80.76, 'Price Return %': 14.02, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 14.02, 'Volatility %': 35.18, 'Avg Daily Volume': 3277615, 'Momentum ($)': 9.93, 'ROE': 1.47, 'P/E Ratio': 293.29}
# [129/502] Checking: COST
#  Appending: {'Ticker': 'COST', 'Company Name': 'Costco', 'Start Price': 907.62, 'End Price': 985.14, 'Price Return %': 8.54, 'Q1 Dividends ($)': 2.46, 'Dividend Yield %': 0.27, 'Total Return %': 8.81, 'Volatility %': 25.86, 'Avg Daily Volume': 2241061, 'Momentum ($)': 77.52, 'ROE': 32.08, 'P/E Ratio': 56.14}
# [130/502] Checking: CTRA
#  Appending: {'Ticker': 'CTRA', 'Company Name': 'Coterra', 'Start Price': 25.7, 'End Price': 25.61, 'Price Return %': -0.35, 'Q1 Dividends ($)': 0.44, 'Dividend Yield %': 1.71, 'Total Return %': 1.36, 'Volatility %': 34.67, 'Avg Daily Volume': 7210527, 'Momentum ($)': -0.09, 'ROE': 9.4, 'P/E Ratio': 14.75}
# [131/502] Checking: CRWD
#  Appending: {'Ticker': 'CRWD', 'Company Name': 'CrowdStrike', 'Start Price': 347.34, 'End Price': 499.33, 'Price Return %': 43.76, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 43.76, 'Volatility %': 53.71, 'Avg Daily Volume': 3992160, 'Momentum ($)': 151.99, 'ROE': -5.74, 'P/E Ratio': None}
# [132/502] Checking: CCI
#  Appending: {'Ticker': 'CCI', 'Company Name': 'Crown Castle', 'Start Price': 86.86, 'End Price': 100.65, 'Price Return %': 15.88, 'Q1 Dividends ($)': 2.63, 'Dividend Yield %': 3.03, 'Total Return %': 18.9, 'Volatility %': 30.52, 'Avg Daily Volume': 3291126, 'Momentum ($)': 13.79, 'ROE': -163.21, 'P/E Ratio': None}
# [133/502] Checking: CSX
#  Appending: {'Ticker': 'CSX', 'Company Name': 'CSX Corporation', 'Start Price': 31.9, 'End Price': 32.91, 'Price Return %': 3.18, 'Q1 Dividends ($)': 0.26, 'Dividend Yield %': 0.82, 'Total Return %': 3.99, 'Volatility %': 25.92, 'Avg Daily Volume': 15488230, 'Momentum ($)': 1.01, 'ROE': 26.12, 'P/E Ratio': 20.0}
# [134/502] Checking: CMI
#  Appending: {'Ticker': 'CMI', 'Company Name': 'Cummins', 'Start Price': 344.05, 'End Price': 325.72, 'Price Return %': -5.33, 'Q1 Dividends ($)': 3.64, 'Dividend Yield %': 1.06, 'Total Return %': -4.27, 'Volatility %': 36.13, 'Avg Daily Volume': 866808, 'Momentum ($)': -18.33, 'ROE': 26.19, 'P/E Ratio': 16.34}
# [135/502] Checking: CVS
#  Appending: {'Ticker': 'CVS', 'Company Name': 'CVS Health', 'Start Price': 43.22, 'End Price': 68.49, 'Price Return %': 58.47, 'Q1 Dividends ($)': 1.33, 'Dividend Yield %': 3.08, 'Total Return %': 61.55, 'Volatility %': 37.64, 'Avg Daily Volume': 10488197, 'Momentum ($)': 25.27, 'ROE': 6.93, 'P/E Ratio': 16.09}
# [136/502] Checking: DHR
#  Appending: {'Ticker': 'DHR', 'Company Name': 'Danaher Corporation', 'Start Price': 229.1, 'End Price': 198.8, 'Price Return %': -13.22, 'Q1 Dividends ($)': 0.64, 'Dividend Yield %': 0.28, 'Total Return %': -12.94, 'Volatility %': 37.24, 'Avg Daily Volume': 4290004, 'Momentum ($)': -30.3, 'ROE': 7.22, 'P/E Ratio': 39.38}
# [137/502] Checking: DRI
#  Appending: {'Ticker': 'DRI', 'Company Name': 'Darden Restaurants', 'Start Price': 183.77, 'End Price': 216.13, 'Price Return %': 17.61, 'Q1 Dividends ($)': 2.8, 'Dividend Yield %': 1.52, 'Total Return %': 19.13, 'Volatility %': 27.66, 'Avg Daily Volume': 1397489, 'Momentum ($)': 32.36, 'ROE': 46.16, 'P/E Ratio': 24.81}
# [138/502] Checking: DVA
#  Appending: {'Ticker': 'DVA', 'Company Name': 'DaVita', 'Start Price': 149.82, 'End Price': 141.67, 'Price Return %': -5.44, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -5.44, 'Volatility %': 32.99, 'Avg Daily Volume': 872471, 'Momentum ($)': -8.15, 'ROE': 54.79, 'P/E Ratio': 14.14}
# [139/502] Checking: DAY
#  Appending: {'Ticker': 'DAY', 'Company Name': 'Dayforce', 'Start Price': 71.39, 'End Price': 55.14, 'Price Return %': -22.76, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -22.76, 'Volatility %': 43.42, 'Avg Daily Volume': 1972243, 'Momentum ($)': -16.25, 'ROE': 1.03, 'P/E Ratio': 357.94}
# [140/502] Checking: DECK
#  Appending: {'Ticker': 'DECK', 'Company Name': 'Deckers Brands', 'Start Price': 204.54, 'End Price': 104.2, 'Price Return %': -49.06, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -49.06, 'Volatility %': 64.15, 'Avg Daily Volume': 3318571, 'Momentum ($)': -100.34, 'ROE': 41.82, 'P/E Ratio': 16.78}
# [141/502] Checking: DE
#  Appending: {'Ticker': 'DE', 'Company Name': 'Deere & Company', 'Start Price': 415.41, 'End Price': 511.72, 'Price Return %': 23.18, 'Q1 Dividends ($)': 3.24, 'Dividend Yield %': 0.78, 'Total Return %': 23.96, 'Volatility %': 31.63, 'Avg Daily Volume': 1384755, 'Momentum ($)': 96.31, 'ROE': 23.91, 'P/E Ratio': 25.19}
# [142/502] Checking: DELL
# ...
# [457/502] Checking: UDR
#  Appending: {'Ticker': 'UDR', 'Company Name': 'UDR, Inc.', 'Start Price': 41.65, 'End Price': 40.71, 'Price Return %': -2.26, 'Q1 Dividends ($)': 0.86, 'Dividend Yield %': 2.05, 'Total Return %': -0.21, 'Volatility %': 26.84, 'Avg Daily Volume': 2251325, 'Momentum ($)': -0.94, 'ROE': 2.85, 'P/E Ratio': 113.33}
# [458/502] Checking: ULTA
#  Appending: {'Ticker': 'ULTA', 'Company Name': 'Ulta Beauty', 'Start Price': 429.16, 'End Price': 458.27, 'Price Return %': 6.78, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 6.78, 'Volatility %': 43.88, 'Avg Daily Volume': 962528, 'Momentum ($)': 29.11, 'ROE': 50.43, 'P/E Ratio': 18.69}
# [459/502] Checking: UNP
#  Appending: {'Ticker': 'UNP', 'Company Name': 'Union Pacific Corporation', 'Start Price': 226.49, 'End Price': 231.41, 'Price Return %': 2.17, 'Q1 Dividends ($)': 2.68, 'Dividend Yield %': 1.18, 'Total Return %': 3.35, 'Volatility %': 26.54, 'Avg Daily Volume': 3058747, 'Momentum ($)': 4.92, 'ROE': 42.47, 'P/E Ratio': 21.27}
# [460/502] Checking: UAL
#  Appending: {'Ticker': 'UAL', 'Company Name': 'United Airlines Holdings', 'Start Price': 95.43, 'End Price': 79.18, 'Price Return %': -17.03, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -17.03, 'Volatility %': 68.62, 'Avg Daily Volume': 8386069, 'Momentum ($)': -16.25, 'ROE': 33.57, 'P/E Ratio': 7.49}
# [461/502] Checking: UPS
#  Appending: {'Ticker': 'UPS', 'Company Name': 'United Parcel Service', 'Start Price': 120.15, 'End Price': 101.18, 'Price Return %': -15.79, 'Q1 Dividends ($)': 3.28, 'Dividend Yield %': 2.73, 'Total Return %': -13.06, 'Volatility %': 36.46, 'Avg Daily Volume': 6097726, 'Momentum ($)': -18.97, 'ROE': 35.91, 'P/E Ratio': 15.2}
# [462/502] Checking: URI
#  Appending: {'Ticker': 'URI', 'Company Name': 'United Rentals', 'Start Price': 686.48, 'End Price': 752.62, 'Price Return %': 9.63, 'Q1 Dividends ($)': 3.58, 'Dividend Yield %': 0.52, 'Total Return %': 10.16, 'Volatility %': 41.91, 'Avg Daily Volume': 667521, 'Momentum ($)': 66.14, 'ROE': 30.17, 'P/E Ratio': 20.54}
# [463/502] Checking: UNH
#  Appending: {'Ticker': 'UNH', 'Company Name': 'UnitedHealth Group', 'Start Price': 498.82, 'End Price': 309.11, 'Price Return %': -38.03, 'Q1 Dividends ($)': 4.31, 'Dividend Yield %': 0.86, 'Total Return %': -37.17, 'Volatility %': 56.03, 'Avg Daily Volume': 11092072, 'Momentum ($)': -189.71, 'ROE': 22.7, 'P/E Ratio': 12.92}
# [464/502] Checking: UHS
#  Appending: {'Ticker': 'UHS', 'Company Name': 'Universal Health Services', 'Start Price': 179.28, 'End Price': 178.08, 'Price Return %': -0.67, 'Q1 Dividends ($)': 0.4, 'Dividend Yield %': 0.22, 'Total Return %': -0.44, 'Volatility %': 38.09, 'Avg Daily Volume': 821921, 'Momentum ($)': -1.2, 'ROE': 18.47, 'P/E Ratio': 10.36}
# [465/502] Checking: VLO
#  Appending: {'Ticker': 'VLO', 'Company Name': 'Valero Energy', 'Start Price': 121.12, 'End Price': 134.69, 'Price Return %': 11.2, 'Q1 Dividends ($)': 2.26, 'Dividend Yield %': 1.87, 'Total Return %': 13.07, 'Volatility %': 44.18, 'Avg Daily Volume': 3401493, 'Momentum ($)': 13.57, 'ROE': 3.71, 'P/E Ratio': 49.34}
# [466/502] Checking: VTR
#  Appending: {'Ticker': 'VTR', 'Company Name': 'Ventas', 'Start Price': 57.12, 'End Price': 62.4, 'Price Return %': 9.25, 'Q1 Dividends ($)': 0.96, 'Dividend Yield %': 1.68, 'Total Return %': 10.93, 'Volatility %': 26.54, 'Avg Daily Volume': 3202552, 'Momentum ($)': 5.28, 'ROE': 1.38, 'P/E Ratio': 190.7}
# [467/502] Checking: VLTO
#  Appending: {'Ticker': 'VLTO', 'Company Name': 'Veralto', 'Start Price': 100.37, 'End Price': 100.96, 'Price Return %': 0.59, 'Q1 Dividends ($)': 0.22, 'Dividend Yield %': 0.22, 'Total Return %': 0.81, 'Volatility %': 24.79, 'Avg Daily Volume': 1433440, 'Momentum ($)': 0.59, 'ROE': 46.04, 'P/E Ratio': 29.64}
# [468/502] Checking: VRSN
#  Appending: {'Ticker': 'VRSN', 'Company Name': 'Verisign', 'Start Price': 204.54, 'End Price': 287.68, 'Price Return %': 40.65, 'Q1 Dividends ($)': 0.77, 'Dividend Yield %': 0.38, 'Total Return %': 41.02, 'Volatility %': 23.27, 'Avg Daily Volume': 857420, 'Momentum ($)': 83.14, 'ROE': None, 'P/E Ratio': 34.96}
# [469/502] Checking: VRSK
#  Appending: {'Ticker': 'VRSK', 'Company Name': 'Verisk Analytics', 'Start Price': 272.57, 'End Price': 308.66, 'Price Return %': 13.24, 'Q1 Dividends ($)': 0.9, 'Dividend Yield %': 0.33, 'Total Return %': 13.57, 'Volatility %': 23.29, 'Avg Daily Volume': 850730, 'Momentum ($)': 36.09, 'ROE': 468.22, 'P/E Ratio': 44.85}
# [470/502] Checking: VZ
#  Appending: {'Ticker': 'VZ', 'Company Name': 'Verizon', 'Start Price': 38.89, 'End Price': 42.31, 'Price Return %': 8.81, 'Q1 Dividends ($)': 1.36, 'Dividend Yield %': 3.49, 'Total Return %': 12.29, 'Volatility %': 23.5, 'Avg Daily Volume': 22417897, 'Momentum ($)': 3.42, 'ROE': 18.42, 'P/E Ratio': 10.37}
# [471/502] Checking: VRTX
#  Appending: {'Ticker': 'VRTX', 'Company Name': 'Vertex Pharmaceuticals', 'Start Price': 405.76, 'End Price': 441.3, 'Price Return %': 8.76, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 8.76, 'Volatility %': 28.33, 'Avg Daily Volume': 1602178, 'Momentum ($)': 35.54, 'ROE': -5.64, 'P/E Ratio': None}
# [472/502] Checking: VTRS
#  Appending: {'Ticker': 'VTRS', 'Company Name': 'Viatris', 'Start Price': 12.09, 'End Price': 9.01, 'Price Return %': -25.49, 'Q1 Dividends ($)': 0.24, 'Dividend Yield %': 1.98, 'Total Return %': -23.51, 'Volatility %': 40.41, 'Avg Daily Volume': 14021683, 'Momentum ($)': -3.08, 'ROE': -21.25, 'P/E Ratio': None}
# [473/502] Checking: VICI
#  Appending: {'Ticker': 'VICI', 'Company Name': 'Vici Properties', 'Start Price': 28.22, 'End Price': 32.28, 'Price Return %': 14.39, 'Q1 Dividends ($)': 0.87, 'Dividend Yield %': 3.07, 'Total Return %': 17.46, 'Volatility %': 21.31, 'Avg Daily Volume': 6956120, 'Momentum ($)': 4.06, 'ROE': 10.12, 'P/E Ratio': 13.37}
# [474/502] Checking: V
#  Appending: {'Ticker': 'V', 'Company Name': 'Visa Inc.', 'Start Price': 313.35, 'End Price': 348.61, 'Price Return %': 11.25, 'Q1 Dividends ($)': 1.18, 'Dividend Yield %': 0.38, 'Total Return %': 11.63, 'Volatility %': 26.64, 'Avg Daily Volume': 6739773, 'Momentum ($)': 35.26, 'ROE': 50.65, 'P/E Ratio': 36.1}
# [475/502] Checking: VST
#  Appending: {'Ticker': 'VST', 'Company Name': 'Vistra Corp.', 'Start Price': 149.21, 'End Price': 195.04, 'Price Return %': 30.71, 'Q1 Dividends ($)': 0.45, 'Dividend Yield %': 0.3, 'Total Return %': 31.01, 'Volatility %': 82.19, 'Avg Daily Volume': 7837955, 'Momentum ($)': 45.83, 'ROE': 41.68, 'P/E Ratio': 30.51}
# [476/502] Checking: VMC
#  Appending: {'Ticker': 'VMC', 'Company Name': 'Vulcan Materials Company', 'Start Price': 254.54, 'End Price': 262.18, 'Price Return %': 3.0, 'Q1 Dividends ($)': 0.98, 'Dividend Yield %': 0.39, 'Total Return %': 3.39, 'Volatility %': 28.14, 'Avg Daily Volume': 1085941, 'Momentum ($)': 7.64, 'ROE': 12.07, 'P/E Ratio': 37.45}
# [477/502] Checking: WRB
#  Appending: {'Ticker': 'WRB', 'Company Name': 'W. R. Berkley Corporation', 'Start Price': 57.47, 'End Price': 72.29, 'Price Return %': 25.78, 'Q1 Dividends ($)': 0.67, 'Dividend Yield %': 1.17, 'Total Return %': 26.95, 'Volatility %': 25.44, 'Avg Daily Volume': 1862298, 'Momentum ($)': 14.82, 'ROE': 20.69, 'P/E Ratio': 16.59}
# [478/502] Checking: GWW
#  Appending: {'Ticker': 'GWW', 'Company Name': 'W. W. Grainger', 'Start Price': 1037.38, 'End Price': 1028.75, 'Price Return %': -0.83, 'Q1 Dividends ($)': 4.31, 'Dividend Yield %': 0.42, 'Total Return %': -0.42, 'Volatility %': 22.84, 'Avg Daily Volume': 271666, 'Momentum ($)': -8.63, 'ROE': 54.16, 'P/E Ratio': 26.96}
# [479/502] Checking: WAB
#  Appending: {'Ticker': 'WAB', 'Company Name': 'Wabtec', 'Start Price': 188.49, 'End Price': 207.69, 'Price Return %': 10.19, 'Q1 Dividends ($)': 0.5, 'Dividend Yield %': 0.27, 'Total Return %': 10.45, 'Volatility %': 34.24, 'Avg Daily Volume': 1049369, 'Momentum ($)': 19.2, 'ROE': 10.68, 'P/E Ratio': 33.55}
# [480/502] Checking: WBA
#  Appending: {'Ticker': 'WBA', 'Company Name': 'Walgreens Boots Alliance', 'Start Price': 9.19, 'End Price': 11.45, 'Price Return %': 24.59, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 24.59, 'Volatility %': 58.71, 'Avg Daily Volume': 18156592, 'Momentum ($)': 2.26, 'ROE': -69.58, 'P/E Ratio': None}
# [481/502] Checking: WMT
#  Appending: {'Ticker': 'WMT', 'Company Name': 'Walmart', 'Start Price': 89.54, 'End Price': 97.27, 'Price Return %': 8.64, 'Q1 Dividends ($)': 0.47, 'Dividend Yield %': 0.52, 'Total Return %': 9.16, 'Volatility %': 28.97, 'Avg Daily Volume': 20277670, 'Momentum ($)': 7.73, 'ROE': 21.78, 'P/E Ratio': 42.03}
# [482/502] Checking: DIS
#  Appending: {'Ticker': 'DIS', 'Company Name': 'Walt Disney Company (The)', 'Start Price': 110.35, 'End Price': 122.34, 'Price Return %': 10.87, 'Q1 Dividends ($)': 0.5, 'Dividend Yield %': 0.45, 'Total Return %': 11.32, 'Volatility %': 37.3, 'Avg Daily Volume': 10222150, 'Momentum ($)': 11.99, 'ROE': 8.89, 'P/E Ratio': 25.31}
# [483/502] Checking: WBD
#  Appending: {'Ticker': 'WBD', 'Company Name': 'Warner Bros. Discovery', 'Start Price': 10.66, 'End Price': 11.3, 'Price Return %': 6.0, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': 6.0, 'Volatility %': 60.72, 'Avg Daily Volume': 41324602, 'Momentum ($)': 0.64, 'ROE': -27.28, 'P/E Ratio': None}
# [484/502] Checking: WM
#  Appending: {'Ticker': 'WM', 'Company Name': 'Waste Management', 'Start Price': 199.11, 'End Price': 228.26, 'Price Return %': 14.64, 'Q1 Dividends ($)': 1.65, 'Dividend Yield %': 0.83, 'Total Return %': 15.47, 'Volatility %': 19.7, 'Avg Daily Volume': 1732344, 'Momentum ($)': 29.15, 'ROE': 34.01, 'P/E Ratio': 34.25}
# [485/502] Checking: WAT
#  Appending: {'Ticker': 'WAT', 'Company Name': 'Waters Corporation', 'Start Price': 368.26, 'End Price': 352.41, 'Price Return %': -4.3, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -4.3, 'Volatility %': 37.5, 'Avg Daily Volume': 514807, 'Momentum ($)': -15.85, 'ROE': 40.82, 'P/E Ratio': 31.75}
# [486/502] Checking: WEC
#  Appending: {'Ticker': 'WEC', 'Company Name': 'WEC Energy Group', 'Start Price': 92.38, 'End Price': 103.13, 'Price Return %': 11.64, 'Q1 Dividends ($)': 1.79, 'Dividend Yield %': 1.93, 'Total Return %': 13.57, 'Volatility %': 19.72, 'Avg Daily Volume': 2284387, 'Momentum ($)': 10.75, 'ROE': 12.58, 'P/E Ratio': 20.34}
# [487/502] Checking: WFC
#  Appending: {'Ticker': 'WFC', 'Company Name': 'Wells Fargo', 'Start Price': 69.46, 'End Price': 79.5, 'Price Return %': 14.45, 'Q1 Dividends ($)': 0.8, 'Dividend Yield %': 1.15, 'Total Return %': 15.6, 'Volatility %': 33.48, 'Avg Daily Volume': 17326027, 'Momentum ($)': 10.04, 'ROE': 11.02, 'P/E Ratio': 15.04}
# [488/502] Checking: WELL
#  Appending: {'Ticker': 'WELL', 'Company Name': 'Welltower', 'Start Price': 123.59, 'End Price': 152.13, 'Price Return %': 23.09, 'Q1 Dividends ($)': 1.34, 'Dividend Yield %': 1.08, 'Total Return %': 24.17, 'Volatility %': 24.39, 'Avg Daily Volume': 3089345, 'Momentum ($)': 28.54, 'ROE': 3.48, 'P/E Ratio': 86.8}
# [489/502] Checking: WST
#  Appending: {'Ticker': 'WST', 'Company Name': 'West Pharmaceutical Services', 'Start Price': 327.86, 'End Price': 218.87, 'Price Return %': -33.24, 'Q1 Dividends ($)': 0.42, 'Dividend Yield %': 0.13, 'Total Return %': -33.11, 'Volatility %': 65.91, 'Avg Daily Volume': 887251, 'Momentum ($)': -108.99, 'ROE': 17.42, 'P/E Ratio': 34.84}
# [490/502] Checking: WDC
#  Appending: {'Ticker': 'WDC', 'Company Name': 'Western Digital', 'Start Price': 46.68, 'End Price': 63.29, 'Price Return %': 35.59, 'Q1 Dividends ($)': 0.1, 'Dividend Yield %': 0.21, 'Total Return %': 35.8, 'Volatility %': 54.93, 'Avg Daily Volume': 8220124, 'Momentum ($)': 16.61, 'ROE': 13.56, 'P/E Ratio': 22.63}
# [491/502] Checking: WY
#  Appending: {'Ticker': 'WY', 'Company Name': 'Weyerhaeuser', 'Start Price': 27.57, 'End Price': 25.85, 'Price Return %': -6.24, 'Q1 Dividends ($)': 0.42, 'Dividend Yield %': 1.52, 'Total Return %': -4.72, 'Volatility %': 29.81, 'Avg Daily Volume': 3912231, 'Momentum ($)': -1.72, 'ROE': 3.71, 'P/E Ratio': 53.94}
# [492/502] Checking: WSM
#  Appending: {'Ticker': 'WSM', 'Company Name': 'Williams-Sonoma, Inc.', 'Start Price': 186.12, 'End Price': 164.22, 'Price Return %': -11.76, 'Q1 Dividends ($)': 1.23, 'Dividend Yield %': 0.66, 'Total Return %': -11.1, 'Volatility %': 49.19, 'Avg Daily Volume': 2118521, 'Momentum ($)': -21.9, 'ROE': 50.15, 'P/E Ratio': 20.05}
# [493/502] Checking: WMB
#  Appending: {'Ticker': 'WMB', 'Company Name': 'Williams Companies', 'Start Price': 54.92, 'End Price': 62.67, 'Price Return %': 14.11, 'Q1 Dividends ($)': 1.0, 'Dividend Yield %': 1.82, 'Total Return %': 15.93, 'Volatility %': 30.75, 'Avg Daily Volume': 7913662, 'Momentum ($)': 7.75, 'ROE': 16.2, 'P/E Ratio': 31.53}
# [494/502] Checking: WTW
#  Appending: {'Ticker': 'WTW', 'Company Name': 'Willis Towers Watson', 'Start Price': 307.49, 'End Price': 303.58, 'Price Return %': -1.27, 'Q1 Dividends ($)': 1.84, 'Dividend Yield %': 0.6, 'Total Return %': -0.67, 'Volatility %': 23.05, 'Avg Daily Volume': 636558, 'Momentum ($)': -3.91, 'ROE': -0.48, 'P/E Ratio': None}
# [495/502] Checking: WDAY
#  Appending: {'Ticker': 'WDAY', 'Company Name': 'Workday, Inc.', 'Start Price': 251.84, 'End Price': 237.37, 'Price Return %': -5.75, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -5.75, 'Volatility %': 38.4, 'Avg Daily Volume': 2270255, 'Momentum ($)': -14.47, 'ROE': 5.7, 'P/E Ratio': 135.06}
# [496/502] Checking: WYNN
#  Appending: {'Ticker': 'WYNN', 'Company Name': 'Wynn Resorts', 'Start Price': 83.36, 'End Price': 94.68, 'Price Return %': 13.59, 'Q1 Dividends ($)': 0.5, 'Dividend Yield %': 0.6, 'Total Return %': 14.19, 'Volatility %': 45.45, 'Avg Daily Volume': 2607279, 'Momentum ($)': 11.32, 'ROE': None, 'P/E Ratio': 28.24}
# [497/502] Checking: XEL
#  Appending: {'Ticker': 'XEL', 'Company Name': 'Xcel Energy', 'Start Price': 65.22, 'End Price': 67.78, 'Price Return %': 3.93, 'Q1 Dividends ($)': 1.69, 'Dividend Yield %': 2.59, 'Total Return %': 6.52, 'Volatility %': 22.94, 'Avg Daily Volume': 3763793, 'Momentum ($)': 2.56, 'ROE': 10.26, 'P/E Ratio': 20.06}
# [498/502] Checking: XYL
#  Appending: {'Ticker': 'XYL', 'Company Name': 'Xylem Inc.', 'Start Price': 115.22, 'End Price': 128.23, 'Price Return %': 11.29, 'Q1 Dividends ($)': 0.8, 'Dividend Yield %': 0.69, 'Total Return %': 11.98, 'Volatility %': 26.98, 'Avg Daily Volume': 1572364, 'Momentum ($)': 13.01, 'ROE': 8.51, 'P/E Ratio': 35.75}
# [499/502] Checking: YUM
#  Appending: {'Ticker': 'YUM', 'Company Name': 'Yum! Brands', 'Start Price': 132.28, 'End Price': 148.41, 'Price Return %': 12.19, 'Q1 Dividends ($)': 1.42, 'Dividend Yield %': 1.07, 'Total Return %': 13.26, 'Volatility %': 27.07, 'Avg Daily Volume': 2203862, 'Momentum ($)': 16.13, 'ROE': None, 'P/E Ratio': 29.82}
# [500/502] Checking: ZBRA
#  Appending: {'Ticker': 'ZBRA', 'Company Name': 'Zebra Technologies', 'Start Price': 383.76, 'End Price': 309.26, 'Price Return %': -19.41, 'Q1 Dividends ($)': 0.0, 'Dividend Yield %': 0.0, 'Total Return %': -19.41, 'Volatility %': 51.63, 'Avg Daily Volume': 606738, 'Momentum ($)': -74.5, 'ROE': 16.16, 'P/E Ratio': 30.57}
# [501/502] Checking: ZBH
#  Appending: {'Ticker': 'ZBH', 'Company Name': 'Zimmer Biomet', 'Start Price': 103.97, 'End Price': 91.46, 'Price Return %': -12.03, 'Q1 Dividends ($)': 0.48, 'Dividend Yield %': 0.46, 'Total Return %': -11.57, 'Volatility %': 29.67, 'Avg Daily Volume': 2156036, 'Momentum ($)': -12.51, 'ROE': 7.32, 'P/E Ratio': 20.82}
# [502/502] Checking: ZTS
#  Appending: {'Ticker': 'ZTS', 'Company Name': 'Zoetis', 'Start Price': 161.57, 'End Price': 156.17, 'Price Return %': -3.34, 'Q1 Dividends ($)': 1.0, 'Dividend Yield %': 0.62, 'Total Return %': -2.73, 'Volatility %': 30.3, 'Avg Daily Volume': 3037886, 'Momentum ($)': -5.4, 'ROE': 52.09, 'P/E Ratio': 28.58}
#
# ✅ Completed. Total stocks found: 498

# %%
# Create a full dataframe of results
performers = pd.DataFrame(results)
print(performers)
# Out:
#     Ticker         Company Name  Start Price  End Price  Price Return %  \
# 0      MMM                   3M       128.43     152.02           18.36
# 1      AOS          A. O. Smith        66.65      65.65           -1.50
# 2      ABT  Abbott Laboratories       112.33     134.38           19.63
# 3     ABBV               AbbVie       176.14     182.31            3.51
# 4      ACN            Accenture       345.63     295.46          -14.52
# ..     ...                  ...          ...        ...             ...
# 493    XYL           Xylem Inc.       115.22     128.23           11.29
# 494    YUM          Yum! Brands       132.28     148.41           12.19
# 495   ZBRA   Zebra Technologies       383.76     309.26          -19.41
# 496    ZBH        Zimmer Biomet       103.97      91.46          -12.03
# 497    ZTS               Zoetis       161.57     156.17           -3.34
#
#      Q1 Dividends ($)  Dividend Yield %  Total Return %  Volatility %  \
# 0                1.46              1.14           19.50         34.98
# 1                0.68              1.02           -0.48         26.80
# 2                1.18              1.05           20.68         23.48
# 3                3.28              1.86            5.37         28.84
# 4                2.96              0.86          -13.66         30.10
# ..                ...               ...             ...           ...
# 493              0.80              0.69           11.98         26.98
# 494              1.42              1.07           13.26         27.07
# 495              0.00              0.00          -19.41         51.63
# 496              0.48              0.46          -11.57         29.67
# 497              1.00              0.62           -2.73         30.30
#
#      Avg Daily Volume  Momentum ($)    ROE  P/E Ratio
# 0             3878507         23.59  93.82      19.05
# 1             1582531         -1.00  27.97      18.97
# 2             6853778         22.05  30.65      17.46
# 3             7103250          6.17  88.40      80.54
# 4             3352561        -50.17  26.93      24.27
# ..                ...           ...    ...        ...
# 493           1572364         13.01   8.51      35.75
# 494           2203862         16.13    NaN      29.82
# 495            606738        -74.50  16.16      30.57
# 496           2156036        -12.51   7.32      20.82
# 497           3037886         -5.40  52.09      28.58
#
# [498 rows x 13 columns]

# %%
# Custom weighted scoring model to rank the best performing stocks

def normalize(series, inverse=False):
    norm = (series - series.min()) / (series.max() - series.min())
    return 1 - norm if inverse else norm

performers["Score_Value"] = normalize(performers["P/E Ratio"], inverse=True)
performers["Score_Growth"] = normalize(performers["Price Return %"])
performers["Score_Quality"] = normalize(performers["ROE"])
performers["Score_Yield"] = normalize(performers["Dividend Yield %"])
performers["Score_Stability"] = normalize(performers["Volatility %"], inverse=True)
performers["Score_Liquidity"] = normalize(performers["Avg Daily Volume"])


performers["Final Score"] = (
    0.25 * performers["Score_Quality"] +
    0.20 * performers["Score_Growth"] +
    0.15 * performers["Score_Value"]+
    0.15 * performers["Score_Yield"] +
    0.15 * performers["Score_Stability"] +
    0.10 * performers["Score_Liquidity"]
)

# %%
#  Rank the top 10 stocks based on final score
top_10_best = performers.nlargest(10, "Final Score") 
print(top_10_best[["Ticker", "Final Score"]])
# Out:
#     Ticker  Final Score
# 222    HCA     0.649194
# 197      F     0.575569
# 134    CVS     0.544283
# 299    MAS     0.524012
# 465     VZ     0.505620
# 47       T     0.503825
# 468   VICI     0.497689
# 388      O     0.493093
# 202    BEN     0.488294
# 189   FAST     0.483847

# %%
# Flag the final 10 with a True/False indicator
performers["Best Performers"] = performers["Ticker"].isin(top_10_best["Ticker"])

# %%
# Assign investment strategies dynamically using custom logic

def assign_strategy(row):
    
    if row["Ticker"] in aristocrat_tickers:
        return "Income-Focused"
    elif row["Price Return %"] >=10 and row["Dividend Yield %"] <1:
        return "Growth-Focused"
    elif row["Price Return %"] >=5 and row["Dividend Yield %"] >= 1:
        return "Balanced"
    else:
        return "Unclassified"

performers["Strategy"] = performers.apply(assign_strategy, axis=1)

# %%
# Select top 10 for each strategy using sorting metric
top_growth = performers[performers["Strategy"] == "Growth-Focused"].sort_values(by="Price Return %", ascending=False).head(10)
top_income = performers[performers["Strategy"] == "Income-Focused"].sort_values(by="Total Return %", ascending=False).head(10)
top_balanced = performers[performers["Strategy"] == "Balanced"].sort_values(by="Total Return %", ascending=False).head(10)
top_unclassified = performers[performers["Strategy"] == "Unclassified"].sort_values(by="Total Return %", ascending=False).head(10)

# %%
# Stack all top 10s across different strategies into one dataframe and flag the best performers based on final score
final_output = pd.concat([
    top_growth.assign(Strategy="Growth-Focused"),
    top_income.assign(Strategy="Income-Focused"),
    top_balanced.assign(Strategy="Balanced"),
    performers[performers["Best Performers"]]
]).drop_duplicates(subset=["Ticker", "Strategy"]).reset_index(drop=True)

print(final_output)
# Out:
#    Ticker                   Company Name  Start Price  End Price  \
# 0     NRG                     NRG Energy        91.98     162.67
# 1    PLTR          Palantir Technologies        75.19     130.74
# 2     HWM               Howmet Aerospace       110.63     184.90
# 3    SMCI                     Supermicro        30.05      47.58
# 4     GEV                     GE Vernova       338.68     519.66
# 5     JBL                          Jabil       142.69     217.37
# 6      GE                   GE Aerospace       168.28     254.51
# 7    NFLX                        Netflix       886.73    1323.12
# 8    UBER                           Uber        63.17      91.53
# 9    CRWD                    CrowdStrike       347.34     499.33
# 10    CAH                Cardinal Health       117.23     166.67
# 11    IBM                            IBM       217.04     289.70
# 12    BEN             Franklin Resources        19.54      23.82
# 13   FAST                       Fastenal        34.77      41.96
# 14   CTAS                         Cintas       181.41     220.75
# 15    ABT            Abbott Laboratories       112.33     134.38
# 16     KO        Coca-Cola Company (The)        60.95      70.33
# 17    ECL                         Ecolab       229.77     267.45
# 18    NUE                          Nucor       113.49     130.88
# 19     ES              Eversource Energy        55.96      63.36
# 20    STX             Seagate Technology        85.24     141.44
# 21    CVS                     CVS Health        43.22      68.49
# 22     DG                 Dollar General        74.56     114.45
# 23     PM    Philip Morris International       119.14     181.03
# 24    NEM                        Newmont        37.97      56.76
# 25    MOS           Mosaic Company (The)        24.01      35.32
# 26    TPR                 Tapestry, Inc.        65.06      87.11
# 27    HAS                         Hasbro        55.25      73.13
# 28    HII  Huntington Ingalls Industries       185.03     238.65
# 29      T                           AT&T        22.31      28.08
# 30      F             Ford Motor Company         9.21      10.80
# 31    HCA                 HCA Healthcare       296.50     379.30
# 32    MAS                          Masco        70.98      64.17
# 33      O                  Realty Income        51.13      56.76
# 34     VZ                        Verizon        38.89      42.31
# 35   VICI                Vici Properties        28.22      32.28
#
#     Price Return %  Q1 Dividends ($)  Dividend Yield %  Total Return %  \
# 0            76.85              0.88              0.96           77.81
# 1            73.88              0.00              0.00           73.88
# 2            67.13              0.20              0.18           67.31
# 3            58.34              0.00              0.00           58.34
# 4            53.44              0.25              0.07           53.51
# 5            52.33              0.16              0.11           52.44
# 6            51.24              0.36              0.21           51.46
# 7            49.21              0.00              0.00           49.21
# 8            44.89              0.00              0.00           44.89
# 9            43.76              0.00              0.00           43.76
# 10           42.18              1.01              0.86           43.04
# 11           33.48              3.35              1.54           35.02
# 12           21.93              0.64              3.28           25.21
# 13           20.68              0.87              2.50           23.18
# 14           21.68              0.78              0.43           22.11
# 15           19.63              1.18              1.05           20.68
# 16           15.38              1.02              1.67           17.06
# 17           16.40              1.30              0.57           16.96
# 18           15.33              1.10              0.97           16.30
# 19           13.22              1.51              2.69           15.92
# 20           65.94              1.44              1.69           67.63
# 21           58.47              1.33              3.08           61.55
# 22           53.50              1.18              1.58           55.08
# 23           51.94              2.70              2.27           54.21
# 24           49.50              0.50              1.32           50.82
# 25           47.08              0.44              1.83           48.92
# 26           33.89              0.70              1.08           34.97
# 27           32.36              1.40              2.53           34.89
# 28           28.98              2.70              1.46           30.44
# 29           25.88              0.56              2.49           28.37
# 30           17.26              0.45              4.89           22.15
# 31           27.92              1.44              0.49           28.41
# 32           -9.59              0.62              0.87           -8.72
# 33           11.01              1.60              3.14           14.15
# 34            8.81              1.36              3.49           12.29
# 35           14.39              0.87              3.07           17.46
#
#     Volatility %  Avg Daily Volume  ...  P/E Ratio  Score_Value  Score_Growth  \
# 0          67.42           3308117  ...      25.18     0.991735      1.000000
# 1          84.30          99278478  ...     584.17     0.763801      0.976412
# 2          40.48           3100998  ...      59.17     0.977875      0.922802
# 3         105.57          60966690  ...      26.39     0.991241      0.852990
# 4          65.16           3795445  ...      74.07     0.971799      0.814074
# 5          44.50           1444400  ...      43.13     0.984415      0.805258
# 6          36.48           6142929  ...      38.94     0.986124      0.796601
# 7          37.13           4341797  ...      61.36     0.976982      0.780478
# 8          44.44          23379896  ...      16.40     0.995315      0.746168
# 9          53.71           3992160  ...        NaN          NaN      0.737193
# 10         22.40           2481327  ...      25.85     0.991461      0.724645
# 11         33.81           4605136  ...      49.99     0.981618      0.655548
# 12         37.71           4729253  ...      36.06     0.987298      0.563815
# 13         26.36           6663066  ...      43.13     0.984415      0.553888
# 14         24.73           1757017  ...      50.90     0.981247      0.561830
# 15         23.48           6853778  ...      17.46     0.994883      0.545548
# 16         20.00          17485657  ...      28.65     0.990320      0.511794
# 17         22.56           1366707  ...      37.24     0.986817      0.519895
# 18         44.10           2709083  ...      24.32     0.992085      0.511397
# 19         28.31           2871405  ...      28.31     0.990458      0.494639
# 20         50.16           3960174  ...      21.50     0.993235      0.913351
# 21         37.64          10488197  ...      16.09     0.995441      0.854023
# 22         42.11           4077350  ...      21.78     0.993121      0.814550
# 23         27.23           6105121  ...      28.17     0.990515      0.802160
# 24         39.34          12146547  ...      13.64     0.996440      0.782781
# 25         38.22           5755372  ...      32.13     0.988901      0.763561
# 26         46.41           5120265  ...      23.74     0.992322      0.658804
# 27         45.33           1957144  ...      25.62     0.991555      0.646652
# 28         44.91            688077  ...      18.15     0.994601      0.619808
# 29         25.47          38879477  ...      17.40     0.994907      0.595187
# 30         35.44         108242564  ...       9.45     0.998149      0.526725
# 31         30.75           1620710  ...      16.72     0.995184      0.611389
# 32         36.24           2114446  ...      18.14     0.994605      0.313478
# 33         19.58           5634305  ...      52.44     0.980619      0.477087
# 34         23.50          22417897  ...      10.37     0.997774      0.459614
# 35         21.31           6956120  ...      13.37     0.996550      0.503931
#
#     Score_Quality  Score_Yield  Score_Stability  Score_Liquidity  Final Score  \
# 0        0.117650     0.196319         0.380739         0.012388     0.465970
# 1        0.099249     0.000000         0.212275         0.374442     0.403950
# 2        0.108254     0.036810         0.649601         0.011606     0.462427
# 3        0.103602     0.000000         0.000000         0.229908     0.368176
# 4        0.103365     0.014315         0.403293         0.014226     0.398490
# 5        0.110572     0.022495         0.609481         0.005357     0.431689
# 6        0.107638     0.042945         0.689521         0.023082     0.446326
# 7        0.115349     0.000000         0.683034         0.016287     0.435564
# 8        0.131483     0.000000         0.610080         0.088110     0.431724
# 9        0.089017     0.000000         0.517565         0.014968          NaN
# 10            NaN     0.175869         0.830040         0.009269          NaN
# 11       0.104614     0.314928         0.716168         0.017281     0.460898
# 12       0.093845     0.670757         0.677246         0.017749     0.488294
# 13       0.110550     0.511247         0.790519         0.025044     0.483847
# 14       0.115044     0.087935         0.806786         0.006536     0.423176
# 15       0.109589     0.214724         0.819261         0.025764     0.443413
# 16       0.114184     0.341513         0.853992         0.065873     0.465366
# 17       0.106265     0.116564         0.828443         0.005064     0.420825
# 18       0.096445     0.198364         0.613473         0.010128     0.397992
# 19       0.095439     0.550102         0.771058         0.010740     0.470604
# 20            NaN     0.345603         0.552994         0.014848          NaN
# 21       0.096180     0.629857         0.677944         0.039475     0.544283
# 22       0.101137     0.323108         0.633333         0.015290     0.482158
# 23            NaN     0.464213         0.781836         0.022940          NaN
# 24       0.101680     0.269939         0.660978         0.045731     0.475653
# 25       0.094116     0.374233         0.672156         0.021620     0.483697
# 26       0.115027     0.220859         0.590419         0.019224     0.432980
# 27       0.114331     0.517382         0.601198         0.007291     0.475163
# 28       0.099198     0.298569         0.605389         0.002503     0.433795
# 29       0.098413     0.509202         0.799401         0.146583     0.503825
# 30       0.098763     1.000000         0.699900         0.408260     0.575569
# 31       1.000000     0.100204         0.746707         0.006022     0.649194
# 32       0.723451     0.177914         0.691916         0.007884     0.524012
# 33       0.093681     0.642127         0.858184         0.021163     0.493093
# 34       0.102675     0.713701         0.819062         0.084481     0.505620
# 35       0.097983     0.627812         0.840918         0.026150     0.497689
#
#     Best Performers        Strategy
# 0             False  Growth-Focused
# 1             False  Growth-Focused
# 2             False  Growth-Focused
# 3             False  Growth-Focused
# 4             False  Growth-Focused
# 5             False  Growth-Focused
# 6             False  Growth-Focused
# 7             False  Growth-Focused
# 8             False  Growth-Focused
# 9             False  Growth-Focused
# 10            False  Income-Focused
# 11            False  Income-Focused
# 12             True  Income-Focused
# 13             True  Income-Focused
# 14            False  Income-Focused
# 15            False  Income-Focused
# 16            False  Income-Focused
# 17            False  Income-Focused
# 18            False  Income-Focused
# 19            False  Income-Focused
# 20            False        Balanced
# 21             True        Balanced
# 22            False        Balanced
# 23            False        Balanced
# 24            False        Balanced
# 25            False        Balanced
# 26            False        Balanced
# 27            False        Balanced
# 28            False        Balanced
# 29             True        Balanced
# 30             True        Balanced
# 31             True  Growth-Focused
# 32             True    Unclassified
# 33             True  Income-Focused
# 34             True        Balanced
# 35             True        Balanced
#
# [36 rows x 22 columns]

# %%
# Export to excel
final_output.to_excel("Top_10_Year_JuneEnd_2025.xlsx", index=False)
print("\n✅ Exported: Top_10_Year_JuneEnd_2025.xlsx")
# Out:
# ✅ Exported: Top_10_Year_JuneEnd_2025.xlsx
